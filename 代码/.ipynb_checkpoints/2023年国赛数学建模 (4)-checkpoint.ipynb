# %% [markdown]
# # 2023年国赛数学建模
# - 码农：夏霖翰
# - 产品经理：黄宇豪 侯奕时

# %% [markdown]
# ## 数据预处理

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import correlate
from scipy.stats import norm
import seaborn as sns
from googletrans import Translator, LANGUAGES
import random
import dask.dataframe as dd
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.layers import Dense, Input, Flatten, Activation
from tcn import TCN
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from scipy.optimize import minimize

# %%
# 使用dask包读取数据 避免内存报错
Product_stat = pd.read_excel("Data/附件1.xlsx", engine='openpyxl')
Sales_stat = pd.read_csv("Data_treated.csv")
Sales_stat = Sales_stat.set_index("销售日期")
Sales_stat = Sales_stat.dropna()
Sales_stat.head()
# Out:
#            扫码销售时间          单品编码            新码  销量(千克)  销售单价(元/千克) 销售类型 是否打折销售  \
# 销售日期
# 2020/7/1  9:15:08  1.029000e+14  4.401310e+19   0.396         7.6   销售      否
# 2020/7/1  9:17:27  1.029000e+14  4.401310e+19   0.849         3.2   销售      否
# 2020/7/1  9:17:34  1.029000e+14  4.401310e+19   0.409         7.6   销售      否
# 2020/7/1  9:19:45  1.029000e+14  4.401310e+19   0.421        10.0   销售      否
# 2020/7/1  9:20:24  1.029000e+14  4.401310e+19   0.539         8.0   销售      否
#
#              单品名称 品类名称  批发单价    折损量      单品成本      单次成本   单次销售额     单次利润率
# 销售日期
# 2020/7/1  泡泡椒(精品)  辣椒类  4.32   7.08  4.649161  1.841068  3.0096  1.634704
# 2020/7/1      大白菜  花叶类  2.10  22.27  2.701660  2.293709  2.7168  1.184457
# 2020/7/1  泡泡椒(精品)  辣椒类  4.32   7.08  4.649161  1.901507  3.1084  1.634704
# 2020/7/1      上海青  花叶类  7.03  14.43  8.215496  3.458724  4.2100  1.217212
# 2020/7/1       菜心  花叶类  4.60  13.70  5.330243  2.873001  4.3120  1.500870

# %% [markdown]
# #### 数据预处理思路
#
# - 通过观察我们发现只有批发单价存在异常值，第一步的数据预处理需要根据不同单品的平均售价剔除超出三倍sigma的批发单价

# %%
# 计算不同产品的正态分布情况，包括标准差和均值
Normal_distribution_sigmoid = pd.DataFrame(columns=['单品名称', '均值', '标准差'])
Product_type_series = Sales_stat['单品名称'].unique()
for product_name in Product_type_series:
    sub_df = Sales_stat[Sales_stat['单品名称'] == product_name]
    mean_value = sub_df["批发单价"].mean()
    std_deviation = sub_df["批发单价"].std()
    product_data = pd.DataFrame({'单品名称': [product_name],
                                 '均值': [mean_value],
                                 '标准差': [std_deviation]})
    Normal_distribution_sigmoid = Normal_distribution_sigmoid.append(product_data, ignore_index=True)
Normal_distribution_sigmoid.set_index('单品名称', inplace=True)
Normal_distribution_sigmoid.head()
# Out:
#                均值       标准差
# 单品名称
# 泡泡椒(精品)  7.146388  2.979607
# 大白菜      1.250324  0.552749
# 上海青      4.450555  1.143459
# 菜心       4.437266  1.249596
# 云南生菜     5.054784  1.173775

# %%
# 使用 Pandas 的 merge 函数将两个 DataFrame 合并在一起
merged_df = pd.merge(Sales_stat, Normal_distribution_sigmoid, left_on='单品名称', right_index=True, how='left')
# 计算上下界
merged_df['lower_bound'] = merged_df['均值'] - 3 * merged_df['标准差']
merged_df['upper_bound'] = merged_df['均值'] + 3 * merged_df['标准差']
# 过滤数据
Sales_stat_filtered = merged_df.loc[
    (merged_df['批发单价'] >= merged_df['lower_bound']) & 
    (merged_df['批发单价'] <= merged_df['upper_bound'])
]
# 删除临时的边界列
Sales_stat_filtered.drop(['lower_bound', 'upper_bound'], axis=1, inplace=True)
# 将索引转换为日期格式
Sales_stat_filtered.index = pd.to_datetime(Sales_stat_filtered.index)
Sales_stat_filtered.head()
# Out:
# /usr/local/lib64/python3.6/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#              扫码销售时间          单品编码            新码  销量(千克)  销售单价(元/千克) 销售类型  \
# 销售日期
# 2020-07-01  9:15:08  1.029000e+14  4.401310e+19   0.396         7.6   销售
# 2020-07-01  9:17:27  1.029000e+14  4.401310e+19   0.849         3.2   销售
# 2020-07-01  9:17:34  1.029000e+14  4.401310e+19   0.409         7.6   销售
# 2020-07-01  9:19:45  1.029000e+14  4.401310e+19   0.421        10.0   销售
# 2020-07-01  9:20:24  1.029000e+14  4.401310e+19   0.539         8.0   销售
#
#            是否打折销售     单品名称 品类名称  批发单价    折损量      单品成本      单次成本   单次销售额  \
# 销售日期
# 2020-07-01      否  泡泡椒(精品)  辣椒类  4.32   7.08  4.649161  1.841068  3.0096
# 2020-07-01      否      大白菜  花叶类  2.10  22.27  2.701660  2.293709  2.7168
# 2020-07-01      否  泡泡椒(精品)  辣椒类  4.32   7.08  4.649161  1.901507  3.1084
# 2020-07-01      否      上海青  花叶类  7.03  14.43  8.215496  3.458724  4.2100
# 2020-07-01      否       菜心  花叶类  4.60  13.70  5.330243  2.873001  4.3120
#
#                单次利润率        均值       标准差
# 销售日期
# 2020-07-01  1.634704  7.146388  2.979607
# 2020-07-01  1.184457  1.250324  0.552749
# 2020-07-01  1.634704  7.146388  2.979607
# 2020-07-01  1.217212  4.450555  1.143459
# 2020-07-01  1.500870  4.437266  1.249596

# %% [markdown]
# #### 正态分布的数据可视化

# %%
def Normal_distribution_visulable(ax, DataFrame, Product_name):
    filtered_1 = DataFrame[DataFrame['单品名称'] == Product_name]
    mean, std = filtered_1['批发单价'].mean(), filtered_1['批发单价'].std()
    xmin, xmax = filtered_1['批发单价'].min(), filtered_1['批发单价'].max()
    x = np.linspace(xmin, xmax, 100)

    sns.histplot(filtered_1['批发单价'], kde=False, bins=30, ax=ax, label='Data')
    ax.plot(x, norm.pdf(x, mean, std) * 1000, 'k', linewidth=2, label='Fit')
    ax.axvline(mean, color='r', linestyle='--', linewidth=2, label='Mean')
    ax.axvline(mean + 3*std, color='orange', linestyle='--', linewidth=2, label='+3 Std Dev')
    ax.axvline(mean - 3*std, color='orange', linestyle='--', linewidth=2, label='-3 Std Dev')
    ax.set_title('Fit data to normal distribution')
    ax.set_xlabel('Value')
    ax.set_ylabel('Frequency')
    ax.legend()

def Show_all_Normal_distribution(Dataframe, Length, Width):
    Number = Length * Width
    unique_values = Dataframe['单品名称'].unique()
    random_plt_name = random.sample(list(unique_values), Number)

    fig, axes = plt.subplots(Length, Width, figsize=(4*Length, 3*Width))

    for ax, name in zip(axes.flatten(), random_plt_name):
        Normal_distribution_visulable(ax, Dataframe, name)

    plt.tight_layout()
    plt.show()

# %%
Show_all_Normal_distribution(Sales_stat,4,4)
# Out:
# /usr/local/lib64/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /usr/local/lib64/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)

# %% [markdown]
# ## 问题一：相关性分析

# %%
# 统计不同产品的总销量
Stat_according_to_each_product = Sales_stat_filtered.groupby('单品名称')['销量(千克)'].sum().reset_index()
print("根据不同产品的销售统计数据")
Stat_according_to_each_product.head()
# Out:
# 根据不同产品的销售统计数据
#      单品名称    销量(千克)
# 0  七彩椒(1)   260.538
# 1  七彩椒(2)   368.000
# 2  七彩椒(份)    18.000
# 3     上海青  7545.795
# 4  上海青(份)  3070.000

# %%
# 统计不同品类的总销量
Stat_according_to_each_Type = Sales_stat_filtered.groupby('品类名称')['销量(千克)'].sum().reset_index()
print("根据不同品类的销售统计数据")


# 使用 googletrans 库进行翻译
translator = Translator()
translated_labels = [translator.translate(label, src='zh-cn', dest='en').text for label in Stat_according_to_each_Type['品类名称']]

# 绘图
labels = translated_labels  # 使用翻译后的标签
sizes = Stat_according_to_each_Type['销量(千克)']
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')
plt.title('Sales statistics based on different categories')
plt.show()

Stat_according_to_each_Type
# Out:
# 根据不同品类的销售统计数据
#     品类名称      销量(千克)
# 0  水生根茎类   40235.270
# 1    花叶类  196700.759
# 2    花菜类   41427.987
# 3     茄类   22340.298
# 4    辣椒类   90709.195
# 5    食用菌   75561.710

# %%
# 进行每日数据统计
Daily_sales_stat_product = Sales_stat_filtered.groupby(['销售日期', '单品名称']).agg({
    '销量(千克)': 'sum',
    '销售单价(元/千克)': 'sum'
}).reset_index()
Daily_sales_stat_product = Daily_sales_stat_product.rename(columns={
    '销量(千克)': '日销量(千克)',
    '销售单价(元/千克)':'日销售金额(元)'
})

Daily_sales_stat_product = pd.merge(Daily_sales_stat_product, Product_stat, on='单品名称')
print("根据每日销售量的日销量/日销售额统计")
Daily_sales_stat_product.head()
# Out:
# 根据每日销售量的日销量/日销售额统计
#         销售日期    单品名称  日销量(千克)  日销售金额(元)             单品编码        分类编码 分类名称
# 0 2020-07-01  七彩椒(1)    1.909      80.0  102900005117209  1011010504  辣椒类
# 1 2020-07-02  七彩椒(1)    1.825      70.0  102900005117209  1011010504  辣椒类
# 2 2020-07-03  七彩椒(1)    1.581      56.0  102900005117209  1011010504  辣椒类
# 3 2020-07-04  七彩椒(1)    0.693      28.0  102900005117209  1011010504  辣椒类
# 4 2020-07-05  七彩椒(1)    1.395      70.0  102900005117209  1011010504  辣椒类

# %%
# 根据品类统计的每日销售量
Daily_sales_stat_Type = Daily_sales_stat_product.groupby(['销售日期', '分类名称']).agg({
    '日销量(千克)': 'sum',
    '日销售金额(元)': 'sum'
}).reset_index()
Daily_sales_stat_Type.head()
# Out:
#         销售日期   分类名称  日销量(千克)  日销售金额(元)
# 0 2020-07-01  水生根茎类    4.850     209.6
# 1 2020-07-01    花叶类  205.402    3383.7
# 2 2020-07-01    花菜类   46.640    1322.0
# 3 2020-07-01     茄类   35.374     304.0
# 4 2020-07-01    辣椒类   76.715    3206.2

# %% [markdown]
# ### 相关性分析

# %%
# 定义交叉相关性计算函数
def cross_corr_scipy(df_a,df_b):
    x = df_a.values
    y = df_b.values
    # 计算均值
    mean_x = np.mean(x)
    mean_y = np.mean(y)

    # 中心化时间序列（去均值）
    x_centered = x - mean_x
    y_centered = y - mean_y

    # 初始化交叉相关性数组
    cross_corr = np.zeros(2 * len(x) - 1)
    lags = np.arange(-len(x) + 1, len(x))

    # 计算交叉相关性
    for k in range(len(lags)):
        lag = lags[k]
        if lag < 0:
            x_slice = x_centered[:lag + len(x)]
            y_slice = y_centered[-lag:]
        elif lag > 0:
            x_slice = x_centered[lag:]
            y_slice = y_centered[:len(x) - lag]
        else:
            x_slice = x_centered
            y_slice = y_centered

        norm_factor = np.sqrt(np.sum(x_slice ** 2) * np.sum(y_slice ** 2))
        cross_corr[k] = np.sum(x_slice * y_slice) / norm_factor if norm_factor != 0 else 0

    # 绘图
    plt.figure()
    plt.stem(lags, cross_corr)
    #plt.plot(lags, cross_corr, 'r-', linewidth=2)  # 使用平滑的折线图
    plt.xlabel('Lag')
    plt.ylabel('Cross-correlation')
    plt.title('Cross-correlation between x and y')
    plt.show()
    print(np.mean(cross_corr**2))

# %%
# 使用条件筛选
# 对基于品类分类的相关性分析
filtered_root_stock = Daily_sales_stat_Type[Daily_sales_stat_Type['分类名称'] == '水生根茎类']
filtered_Mosaic_leaf_class = Daily_sales_stat_Type[Daily_sales_stat_Type['分类名称'] == '花叶类']
filtered_flower_vegetables = Daily_sales_stat_Type[Daily_sales_stat_Type['分类名称'] == '花菜类']
filtered_solanaceous = Daily_sales_stat_Type[Daily_sales_stat_Type['分类名称'] == '茄类']
filtered_Chili_peppers = Daily_sales_stat_Type[Daily_sales_stat_Type['分类名称'] == '辣椒类']
filtered_mushroomss = Daily_sales_stat_Type[Daily_sales_stat_Type['分类名称'] == '食用菌']

Daily_sales_KG_root_stock = pd.DataFrame()
Daily_sales_KG_Mosaic_leaf_class = pd.DataFrame()
Daily_sales_KG_flower_vegetables = pd.DataFrame()
Daily_sales_KG_solanaceous = pd.DataFrame()
Daily_sales_KG_Chili_peppers = pd.DataFrame()
Daily_sales_KG_mushroomss = pd.DataFrame()
Date_series = pd.DataFrame()

Daily_sales_KG_root_stock['水生根茎类_KG'] = filtered_root_stock["日销量(千克)"]
Daily_sales_KG_Mosaic_leaf_class['花叶类_KG'] = filtered_Mosaic_leaf_class["日销量(千克)"]
Daily_sales_KG_flower_vegetables['花菜类_KG'] = filtered_flower_vegetables["日销量(千克)"]
Daily_sales_KG_solanaceous['茄类_KG'] = filtered_solanaceous["日销量(千克)"]
Daily_sales_KG_Chili_peppers['辣椒类_KG'] = filtered_Chili_peppers["日销量(千克)"]
Daily_sales_KG_mushroomss['食用菌_KG'] = filtered_mushroomss["日销量(千克)"]
Date_series['销售日期'] = Daily_sales_stat_Type["销售日期"]
Date_series = Date_series.drop_duplicates(subset=["销售日期"])

Date_series = Date_series.reset_index(drop=True)
Daily_sales_KG_root_stock = Daily_sales_KG_root_stock.reset_index(drop=True)
Daily_sales_KG_Mosaic_leaf_class = Daily_sales_KG_Mosaic_leaf_class.reset_index(drop=True)
Daily_sales_KG_flower_vegetables = Daily_sales_KG_flower_vegetables.reset_index(drop=True)
Daily_sales_KG_solanaceous = Daily_sales_KG_solanaceous.reset_index(drop=True)
Daily_sales_KG_Chili_peppers = Daily_sales_KG_Chili_peppers.reset_index(drop=True)
Daily_sales_KG_mushroomss = Daily_sales_KG_mushroomss.reset_index(drop=True)

# %%
Saled_KG_according_category_data = pd.DataFrame()
Saled_KG_according_category_data = pd.concat([Date_series, 
                         Daily_sales_KG_root_stock, 
                         Daily_sales_KG_Mosaic_leaf_class, 
                         Daily_sales_KG_flower_vegetables, 
                         Daily_sales_KG_solanaceous, 
                         Daily_sales_KG_Chili_peppers, 
                         Daily_sales_KG_mushroomss],  axis=1)
Saled_KG_according_category_data = Saled_KG_according_category_data.set_index("销售日期")
Saled_KG_according_category_data = Saled_KG_according_category_data.dropna()

Saled_KG_according_category_data.head()
# Out:
#             水生根茎类_KG   花叶类_KG  花菜类_KG   茄类_KG  辣椒类_KG  食用菌_KG
# 销售日期
# 2020-07-01     4.850  205.402  46.640  35.374  76.715  35.365
# 2020-07-02     4.600  196.970  43.943  32.199  66.064  48.510
# 2020-07-03     9.572  187.301  42.076  35.896  64.253  42.442
# 2020-07-04     5.439  231.679  55.662  57.067  81.282  47.262
# 2020-07-05     4.019  220.274  55.474  61.816  98.496  73.213

# %%
cross_corr_scipy(Saled_KG_according_category_data['水生根茎类_KG'],Saled_KG_according_category_data['食用菌_KG'])
# Out:
# 0.07306021005788725

# %% [markdown]
# ## 问题二：最优化决策模型

# %%
Sales_stat_OPT_Raw = Sales_stat_filtered[Sales_stat_filtered["是否打折销售"]=='否']
columns_to_drop = ['均值', '标准差']
Sales_stat_OPT_Raw = Sales_stat_OPT_Raw.drop(columns=columns_to_drop)
Sales_stat_OPT_Raw.head()
# Out:
#              扫码销售时间          单品编码            新码  销量(千克)  销售单价(元/千克) 销售类型  \
# 销售日期
# 2020-07-01  9:15:08  1.029000e+14  4.401310e+19   0.396         7.6   销售
# 2020-07-01  9:17:27  1.029000e+14  4.401310e+19   0.849         3.2   销售
# 2020-07-01  9:17:34  1.029000e+14  4.401310e+19   0.409         7.6   销售
# 2020-07-01  9:19:45  1.029000e+14  4.401310e+19   0.421        10.0   销售
# 2020-07-01  9:20:24  1.029000e+14  4.401310e+19   0.539         8.0   销售
#
#            是否打折销售     单品名称 品类名称  批发单价    折损量      单品成本      单次成本   单次销售额  \
# 销售日期
# 2020-07-01      否  泡泡椒(精品)  辣椒类  4.32   7.08  4.649161  1.841068  3.0096
# 2020-07-01      否      大白菜  花叶类  2.10  22.27  2.701660  2.293709  2.7168
# 2020-07-01      否  泡泡椒(精品)  辣椒类  4.32   7.08  4.649161  1.901507  3.1084
# 2020-07-01      否      上海青  花叶类  7.03  14.43  8.215496  3.458724  4.2100
# 2020-07-01      否       菜心  花叶类  4.60  13.70  5.330243  2.873001  4.3120
#
#                单次利润率
# 销售日期
# 2020-07-01  1.634704
# 2020-07-01  1.184457
# 2020-07-01  1.634704
# 2020-07-01  1.217212
# 2020-07-01  1.500870

# %%
# 计算利润率（加成售价）
Profit_wighted_grouped = Sales_stat_OPT_Raw.groupby([Sales_stat_OPT_Raw.index, '品类名称'])
Profit_wighted_stat = Profit_wighted_grouped.agg(
    销售量之和=pd.NamedAgg(column='销量(千克)', aggfunc='sum'),
    单次成本之和=pd.NamedAgg(column='单次成本', aggfunc='sum'),
    单次销售额之和=pd.NamedAgg(column='单次销售额', aggfunc='sum'),
    总成本 = pd.NamedAgg(column='单次成本', aggfunc='sum'),
).reset_index()

Profit_wighted_stat['单价'] = (Profit_wighted_stat['单次销售额之和'] / Profit_wighted_stat['销售量之和'])
Profit_wighted_stat['平均成本'] = (Profit_wighted_stat['总成本'] / Profit_wighted_stat['销售量之和'])

# 将计算结果放入一个新的DataFrame
Profit_wighted_stat = Profit_wighted_stat[['销售日期', '品类名称', '销售量之和', '单价','平均成本']]
Profit_wighted_stat.set_index('销售日期', inplace=True)
Profit_wighted_stat.head()
# Out:
#              品类名称    销售量之和         单价       平均成本
# 销售日期
# 2020-07-01  水生根茎类    4.850  14.491505  12.622563
# 2020-07-01    花叶类  191.717   7.545755   5.717106
# 2020-07-01    花菜类   46.640  12.704331   9.420016
# 2020-07-01     茄类   35.374   4.998530   4.346075
# 2020-07-01    辣椒类   76.715   9.906670   5.773350

# %%
# 统计不同品类的销售量-利润率
filtered_Profit_root_stock = Profit_wighted_stat[Profit_wighted_stat['品类名称'] == '水生根茎类']
filtered_Profit_Mosaic_leaf_class = Profit_wighted_stat[Profit_wighted_stat['品类名称'] == '花叶类']
filtered_Profit_flower_vegetables = Profit_wighted_stat[Profit_wighted_stat['品类名称'] == '花菜类']
filtered_Profit_solanaceous = Profit_wighted_stat[Profit_wighted_stat['品类名称'] == '茄类']
filtered_Profit_Chili_peppers = Profit_wighted_stat[Profit_wighted_stat['品类名称'] == '辣椒类']
filtered_Profit_mushroomss = Profit_wighted_stat[Profit_wighted_stat['品类名称'] == '食用菌']

#构建空的DataFrame
Profit_root_stock = pd.DataFrame()
Profit_Mosaic_leaf_class = pd.DataFrame()
Profit_flower_vegetables = pd.DataFrame()
Profit_solanaceous = pd.DataFrame()
Profit_Chili_peppers = pd.DataFrame()
Profit_mushroomss = pd.DataFrame()
Sell_root_stock = pd.DataFrame()
Sell_Mosaic_leaf_class = pd.DataFrame()
Sell_flower_vegetables = pd.DataFrame()
Sell_solanaceous = pd.DataFrame()
Sell_Chili_peppers = pd.DataFrame()
Sell_mushroomss = pd.DataFrame()
Cost_root_stock = pd.DataFrame()
Cost_Mosaic_leaf_class = pd.DataFrame()
Cost_flower_vegetables = pd.DataFrame()
Cost_solanaceous = pd.DataFrame()
Cost_Chili_peppers = pd.DataFrame()
Cost_mushroomss = pd.DataFrame()

Profit_root_stock['水生根茎类_售价'] = filtered_Profit_root_stock["单价"]
Profit_Mosaic_leaf_class['花叶类_售价'] = filtered_Profit_Mosaic_leaf_class["单价"]
Profit_flower_vegetables['花菜类_售价'] = filtered_Profit_flower_vegetables["单价"]
Profit_solanaceous['茄类_售价'] = filtered_Profit_solanaceous["单价"]
Profit_Chili_peppers['辣椒类_售价'] = filtered_Profit_Chili_peppers["单价"]
Profit_mushroomss['食用菌_售价'] = filtered_Profit_mushroomss["单价"]

Sell_root_stock['水生根茎类_KG'] = filtered_Profit_root_stock["销售量之和"]
Sell_Mosaic_leaf_class['花叶类_KG'] = filtered_Profit_Mosaic_leaf_class["销售量之和"]
Sell_flower_vegetables['花菜类_KG'] = filtered_Profit_flower_vegetables["销售量之和"]
Sell_solanaceous['茄类_KG'] = filtered_Profit_solanaceous["销售量之和"]
Sell_Chili_peppers['辣椒类_KG'] = filtered_Profit_Chili_peppers["销售量之和"]
Sell_mushroomss['食用菌_KG'] = filtered_Profit_mushroomss["销售量之和"]

Cost_root_stock['水生根茎类_Cost'] = filtered_Profit_root_stock["平均成本"]
Cost_Mosaic_leaf_class['花叶类_Cost'] = filtered_Profit_Mosaic_leaf_class["平均成本"]
Cost_flower_vegetables['花菜类_Cost'] = filtered_Profit_flower_vegetables["平均成本"]
Cost_solanaceous['茄类_Cost'] = filtered_Profit_solanaceous["平均成本"]
Cost_Chili_peppers['辣椒类_Cost'] = filtered_Profit_Chili_peppers["平均成本"]
Cost_mushroomss['食用菌_Cost'] = filtered_Profit_mushroomss["平均成本"]

# %%
Profit_KG_stat_root_stock = pd.DataFrame()
Profit_KG_stat_Mosaic_leaf_class = pd.DataFrame()
Profit_KG_stat_flower_vegetables = pd.DataFrame()
Profit_KG_stat_solanaceous = pd.DataFrame()
Profit_KG_stat_Chili_peppers = pd.DataFrame()
Profit_KG_stat_mushroomss = pd.DataFrame()

Profit_KG_stat_root_stock = pd.concat([
                         Profit_root_stock, 
                         Sell_root_stock,Cost_root_stock
                         ],  axis=1)

Profit_KG_stat_Mosaic_leaf_class = pd.concat([
                         Profit_Mosaic_leaf_class, 
                         Sell_Mosaic_leaf_class,Cost_Mosaic_leaf_class
                         ],  axis=1)

Profit_KG_stat_flower_vegetables = pd.concat([
                         Profit_flower_vegetables, 
                         Sell_flower_vegetables,Cost_flower_vegetables
                         ],  axis=1)

Profit_KG_stat_solanaceous = pd.concat([
                         Profit_solanaceous, 
                         Sell_solanaceous,Cost_solanaceous
                         ],  axis=1)

Profit_KG_stat_Chili_peppers = pd.concat([
                         Profit_Chili_peppers, 
                         Sell_Chili_peppers,Cost_Chili_peppers
                         ],  axis=1)

Profit_KG_stat_mushroomss = pd.concat([
                         Profit_mushroomss, 
                         Sell_mushroomss,Cost_mushroomss
                         ],  axis=1)

Target_frame_list = [Profit_KG_stat_root_stock,
                     Profit_KG_stat_Mosaic_leaf_class,
                     Profit_KG_stat_flower_vegetables,
                     Profit_KG_stat_solanaceous,
                     Profit_KG_stat_Chili_peppers,
                     Profit_KG_stat_mushroomss]

# %%
def add_profit_Dataframe(Dataframe):
    Dataframe['利润率'] = pd.DataFrame(Dataframe.iloc[:, 0] / Dataframe.iloc[:, 2])-1
    return Dataframe

for frame in Target_frame_list:
    add_profit_Dataframe(frame)

# %%
# 计算利润率和销售量之间的关系
# 创建一个2x3的subplot，高为2，宽为3
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

# 使用一个字典来存储所有的DataFrame，这样我们可以使用一个循环来绘制所有的图
data_dict = {
    'Root Stock': Profit_KG_stat_root_stock,
    'Mosaic Leaf Class': Profit_KG_stat_Mosaic_leaf_class,
    'Flower Vegetables': Profit_KG_stat_flower_vegetables,
    'Solanaceous': Profit_KG_stat_solanaceous,
    'Chili Peppers': Profit_KG_stat_Chili_peppers,
    'Mushrooms': Profit_KG_stat_mushroomss
}

best_fit_equations = {}  # 用于存储最佳拟合公式

# 循环通过字典绘制每个图
for i, (key, df) in enumerate(data_dict.items()):
    ax = axs[i//3, i%3]
    
    # 提取数据
    x = df.iloc[:, 3].values  
    y = df.iloc[:, 1].values  
    
    # 创建散点图
    ax.scatter(x, y, label='Data Points')
    
    min_mse = float('inf')
    best_degree = 0
    best_p = None
    
    # 尝试从1到6阶多项式
    for degree in range(0,2):
        z = np.polyfit(x, y, degree)
        p = np.poly1d(z)
        mse = mean_squared_error(y, p(x))
        
        if mse < min_mse:
            min_mse = mse
            best_degree = degree
            best_p = p
    
    # 绘制最佳拟合线
    xp = np.linspace(min(x), max(x), 100)
    ax.plot(xp, best_p(xp), '--',color="r", label=f'Best Fit (Degree {best_degree})')
    
    best_fit_equations[key] = best_p

    # 设置图的其他元素
    ax.set_title(f'{key} (Best Degree: {best_degree})')
    ax.set_xlabel('Profit')
    ax.set_ylabel('Sell')
    ax.legend()

plt.tight_layout()
plt.show()

# 单独输出最佳拟合公式
print("Best fit equations:")
for key, equation in best_fit_equations.items():
    print(f"{key}: {equation}")
# Out:
# Best fit equations:
# Root Stock:
# -4.869 x + 35.37
# Mosaic Leaf Class:
# 92.79 x + 123.2
# Flower Vegetables:
# 9.122 x + 32.89
# Solanaceous:
# 3.688 x + 18.86
# Chili Peppers:
# 52.49 x + 50.52
# Mushrooms:
# -23.98 x + 75.07

# %%
# 创建一个2x3的subplot，高为2，宽为3
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

# 使用一个字典来存储所有的DataFrame，这样我们可以使用一个循环来绘制所有的图
data_dict = {
    'Root Stock': Profit_KG_stat_root_stock,
    'Mosaic Leaf Class': Profit_KG_stat_Mosaic_leaf_class,
    'Flower Vegetables': Profit_KG_stat_flower_vegetables,
    'Solanaceous': Profit_KG_stat_solanaceous,
    'Chili Peppers': Profit_KG_stat_Chili_peppers,
    'Mushrooms': Profit_KG_stat_mushroomss
}

best_fit_equations = {}  # 用于存储最佳拟合公式

# 循环通过字典绘制每个图
for i, (key, df) in enumerate(data_dict.items()):
    ax = axs[i//3, i%3]
    
    # 提取数据
    x = df.iloc[:, 0].values  # 假设第一列是利润率
    y = df.iloc[:, 1].values  # 假设第二列是销售量
    
    # 创建散点图
    ax.scatter(x, y, label='Data Points')
    
    min_mse = float('inf')
    best_degree = 0
    best_p = None
    
    # 尝试从1到6阶多项式
    for degree in range(0, 2):
        z = np.polyfit(x, y, degree)
        p = np.poly1d(z)
        mse = mean_squared_error(y, p(x))
        
        if mse < min_mse:
            min_mse = mse
            best_degree = degree
            best_p = p
    
    # 绘制最佳拟合线
    xp = np.linspace(min(x), max(x), 100)
    ax.plot(xp, best_p(xp), '--',color="r", label=f'Best Fit (Degree {best_degree})')
    
    best_fit_equations[key] = best_p

    # 设置图的其他元素
    ax.set_title(f'{key} (Best Degree: {best_degree})')
    ax.set_xlabel('Selling price')
    ax.set_ylabel('Sell')
    ax.legend()

plt.tight_layout()
plt.show()

# 单独输出最佳拟合公式
print("Best fit equations:")
for key, equation in best_fit_equations.items():
    print(f"{key}: {equation}")
# Out:
# Best fit equations:
# Root Stock:
# -2.914 x + 62.26
# Mosaic Leaf Class:
# -11.24 x + 232.6
# Flower Vegetables:
# -3.054 x + 65.47
# Solanaceous:
# -1.096 x + 30.43
# Chili Peppers:
# -2.18 x + 97.75
# Mushrooms:
# -3.453 x + 93.52

# %%
#  根据上面得出的 售价-销量一阶回归方程进行函数实现
def Root_stock_prediction(x):
    return -2.914*x + 62.26

def Mosaic_Leaf_prediction(x):
    return -11.24*x + 232.6

def Flower_Vegetables_prediction(x):
    return -1.096*x + 65.47

def Solanaceous_prediction(x):
    return -2.18*x + 30.43

def Chili_Peppers_prediction(x):
    return -2.18*x + 97.75

def Mushrooms_prediction(x):
    return -3.453*x + 93.52

# %% [markdown]
# ### 训练神经网络模型用于预测成本
# - 我们需要通过季节（二十四节气）和产品过去价格的时间序列，用于预测产品的采购成本
# - 本模型使用特征融合算法，TCN时序卷积算法，注意力机制算法

# %%
# 迁移前面预处理得到的Dataframe结果用于神经网络模型的构建
Profit_KG_stat_root_stock_train = Profit_KG_stat_root_stock
Profit_KG_stat_Mosaic_leaf_class_train = Profit_KG_stat_Mosaic_leaf_class
Profit_KG_stat_flower_vegetables_train = Profit_KG_stat_flower_vegetables
Profit_KG_stat_solanaceous_train = Profit_KG_stat_solanaceous
Profit_KG_stat_Chili_peppers_train = Profit_KG_stat_Chili_peppers
Profit_KG_stat_mushroomss_train = Profit_KG_stat_mushroomss
Target_frame_train_list = [Profit_KG_stat_root_stock_train,
                     Profit_KG_stat_Mosaic_leaf_class_train,
                     Profit_KG_stat_flower_vegetables_train,
                     Profit_KG_stat_solanaceous_train,
                     Profit_KG_stat_Chili_peppers_train,
                     Profit_KG_stat_mushroomss_train]

# %%
# 二十四节气及其对应的月和日
solar_terms = [
    ("立春", (2, 4)), ("雨水", (2, 19)),
    ("惊蛰", (3, 5)), ("春分", (3, 20)),
    ("清明", (4, 4)), ("谷雨", (4, 20)),
    ("立夏", (5, 5)), ("小满", (5, 21)),
    ("芒种", (6, 5)), ("夏至", (6, 21)),
    ("小暑", (7, 6)), ("大暑", (7, 22)),
    ("立秋", (8, 7)), ("处暑", (8, 23)),
    ("白露", (9, 7)), ("秋分", (9, 22)),
    ("寒露", (10, 8)), ("霜降", (10, 23)),
    ("立冬", (11, 7)), ("小雪", (11, 22)),
    ("大雪", (12, 6)), ("冬至", (12, 21)),
    ("小寒", (1, 5)), ("大寒", (1, 20))
]

# 季节和节气的映射
season_to_terms = {
    '春': ["立春", "雨水", "惊蛰", "春分", "清明", "谷雨"],
    '夏': ["立夏", "小满", "芒种", "夏至", "小暑", "大暑"],
    '秋': ["立秋", "处暑", "白露", "秋分", "寒露", "霜降"],
    '冬': ["立冬", "小雪", "大雪", "冬至", "小寒", "大寒"]
}

def find_previous_solar_term(month, day):
    for i in reversed(range(len(solar_terms))):
        term, (term_month, term_day) = solar_terms[i]
        if (month, day) >= (term_month, term_day):
            return term
    return None

def encode_solar_term(month, day):
    term = find_previous_solar_term(month, day)
    if term is None:
        return [0]*10
    
    for season, terms in season_to_terms.items():
        if term in terms:
            season_encoding = [1 if s == season else 0 for s in ['春', '夏', '秋', '冬']]
            term_encoding = [1 if t == term else 0 for t in terms]
            return season_encoding + term_encoding
    return [0]*10

# %%
# 对所有的品类的数据中的日期进行二十四节气编码 准备进行数据预处理
for frame in Target_frame_train_list:
    frame['二十四节气编码'] = frame.index.map(lambda x: encode_solar_term(x.month, x.day))

# %%
def slide_windows(Dataframe,window_size):
    processed_df = pd.DataFrame()
    Total_size = window_size+7
    # 滑动窗口
    for i in range(len(Dataframe) - 22):  # 15天成本 + 7天预测 = 22天窗口
        # 获取过去15天的成本数据
        past_15_days_cost = Dataframe.iloc[:, 2].iloc[i:i+window_size].values

        # 获取未来7天的节气数据
        future_7_days_solar_term = np.array(Dataframe.iloc[:, 4].iloc[i+window_size:i+Total_size].tolist())

        # 将两个数组合并为一个DataFrame行
        row_data = {
            '过去时间窗口成本': list(past_15_days_cost),
            '未来七天节气': future_7_days_solar_term.reshape(-1).tolist(),  # 将7x10的二维数组转换为1D数组
            '未来七天成本': list(Dataframe.iloc[:, 2].iloc[i+window_size:i+Total_size].values)
        }
        processed_df = processed_df.append(row_data, ignore_index=True)
    return processed_df

# %%
Target_frame_train_list_slided = []
for frame in Target_frame_train_list:
    Target_frame_train_list_slided.append(slide_windows(frame,15))

# %%
Scaler_diction_global = {}

def normalize_list(scaler, lst):
    arr = np.array(lst).reshape(-1, 1)
    arr_scaled = scaler.fit_transform(arr)
    return arr_scaled.flatten().tolist()

def MinMaxScaler_prepossecing(DataFrame,name_type):
    scaler_future_cost = MinMaxScaler()
    scaler_future_solar_term = MinMaxScaler()
    scaler_past_cost = MinMaxScaler()
    DataFrame['未来七天成本'] = DataFrame['未来七天成本'].apply(lambda x: normalize_list(scaler_future_cost, x))
    DataFrame['未来七天节气'] = DataFrame['未来七天节气'].apply(lambda x: normalize_list(scaler_future_solar_term, x))
    DataFrame['过去时间窗口成本'] = DataFrame['过去时间窗口成本'].apply(lambda x: normalize_list(scaler_past_cost, x))
    Scaler_diction_global.update({name_type: [scaler_future_cost,
                                             scaler_future_solar_term,
                                             scaler_past_cost]}) 
    return DataFrame

name_type_list = ['水生根茎类','花叶类','花菜类','茄类','辣椒类','食用菌']
Target_frame_train_list_slided_normalized = []
for index in range(len(Target_frame_train_list_slided)):
    Target_frame_train_list_slided_normalized.append(MinMaxScaler_prepossecing(Target_frame_train_list_slided[index],
                                                                               name_type_list[index]))

# %% [markdown]
# ### 神经网络数据进一步预处理，让数据可以在模型这种运行

# %%
def deal_X2(Dataframe):
    list_test = []
    for temp in np.array(Dataframe['未来七天节气']):
        for i in temp:
            list_test.append(i)
    X2 = np.array(list_test).reshape(-1, 70, 1)
    return X2

def df_to_nparray(df_col):
    return np.array([np.array(x) for x in df_col])

def Data_process_defore_train(Dataframe):
    # 获取数据集总长度
    n = len(Dataframe)
    # 计算测试集、验证集和训练集的大小
    test_size = int(n * 0.2)
    val_size = int(n * 0.8 * 0.25)
    train_size = n - test_size - val_size

    # 分离自变量和因变量
    X = Dataframe[["未来七天节气", "过去时间窗口成本"]]
    y = Dataframe["未来七天成本"]

    # 按照顺序切分数据集
    X_train = X.iloc[:train_size]
    y_train = y.iloc[:train_size]

    X_val = X.iloc[train_size:train_size+val_size]
    y_val = y.iloc[train_size:train_size+val_size]

    X_test = X.iloc[train_size+val_size:]
    y_test = y.iloc[train_size+val_size:]

    # 打印各个数据集的大小
    print("Training set:", X_train.shape, y_train.shape)
    print("Validation set:", X_val.shape, y_val.shape)
    print("Test set:", X_test.shape, y_test.shape)
    # 确保X_train, y_train, X_val, y_val, X_test, y_test都已正确加载并预处理
    X1_train = df_to_nparray(X_train['过去时间窗口成本']).reshape(-1, 15, 1)
    X2_train = deal_X2(X_train)
    y_train_array = df_to_nparray(y_train).reshape(-1, 7)

    X1_val = df_to_nparray(X_val['过去时间窗口成本']).reshape(-1, 15, 1)
    X2_val = deal_X2(X_val)

    y_val_array = df_to_nparray(y_val).reshape(-1, 7)

    X1_test = df_to_nparray(X_test['过去时间窗口成本']).reshape(-1, 15, 1)
    X2_test = deal_X2(X_test)

    y_test_array = df_to_nparray(y_test).reshape(-1, 7)
    return {"X1训练集":X1_train,
            "X2训练集":X2_train,
            "X1验证集":X1_val,
            "X2验证集":X2_val,
            "X1测试集":X1_test,
            "X2测试集":X2_test,
            "Y训练集":y_train_array,
            "Y验证集":y_val_array,
            "Y测试集":y_test_array}

# %% [markdown]
# ### 构造模型

# %%
# 注意力机制层
class AttentionLayer(layers.Layer):
    def __init__(self):
        super(AttentionLayer, self).__init__()
        
    def build(self, input_shape):
        self.W = self.add_weight(shape=(input_shape[-1], input_shape[-1]), initializer='random_normal', trainable=True)
        self.b = self.add_weight(shape=(input_shape[-1],), initializer='zeros', trainable=True)
        
    def call(self, inputs):
        q = tf.nn.tanh(tf.linalg.matmul(inputs, self.W) + self.b)
        a = tf.nn.softmax(q, axis=1)
        output = tf.reduce_sum(a * inputs, axis=1)
        return output

class Feature_fusion_TCN_model(Model):
    def __init__(self):
        super(Feature_fusion_TCN_model, self).__init__()
        
        self.tcn1 = TCN()
        self.tcn2 = TCN()
        
        self.concat = layers.Concatenate(axis=1)
        self.attention_layer = AttentionLayer()
        
        self.reshape = layers.Reshape((1, -1))
        self.output_layer = Dense(7, activation='linear')
        
    def call(self, inputs):
        input1, input2 = inputs

        tcn1_output = self.tcn1(input1)
        tcn2_output = self.tcn2(input2)

        merged = self.concat([tcn1_output, tcn2_output])
        
        attention_output = self.attention_layer(merged)
        attention_output_expanded = self.reshape(attention_output)
        
        output = self.output_layer(attention_output_expanded)
        
        return output

# %%
print("模型的顺序为：",name_type_list)
model_root_stock = Feature_fusion_TCN_model()
model_root_stock.compile(optimizer='adam', loss='mse')
model_root_stock.build([(None, 15, 1), (None, 70, 1)]) 

model_flower_leaf = Feature_fusion_TCN_model()
model_flower_leaf.compile(optimizer='adam', loss='mse')
model_flower_leaf.build([(None, 15, 1), (None, 70, 1)]) 

model_flower_veg = Feature_fusion_TCN_model()
model_flower_veg.compile(optimizer='adam', loss='mse')
model_flower_veg.build([(None, 15, 1), (None, 70, 1)]) 

model_Nightshade  = Feature_fusion_TCN_model()
model_Nightshade .compile(optimizer='adam', loss='mse')
model_Nightshade .build([(None, 15, 1), (None, 70, 1)]) 

model_spicy  = Feature_fusion_TCN_model()
model_spicy .compile(optimizer='adam', loss='mse')
model_spicy .build([(None, 15, 1), (None, 70, 1)]) 

model_mushroom  = Feature_fusion_TCN_model()
model_mushroom .compile(optimizer='adam', loss='mse')
model_mushroom .build([(None, 15, 1), (None, 70, 1)]) 

model_list = [model_mushroom,
              model_flower_leaf,
              model_flower_veg,
              model_Nightshade,
              model_spicy,model_mushroom]

print("模型构建完毕，模型结构示例如下：")
model_mushroom.summary()
# Out:
# 模型的顺序为： ['水生根茎类', '花叶类', '花菜类', '茄类', '辣椒类', '食用菌']
# 模型构建完毕，模型结构示例如下：
# Model: "feature_fusion_tcn_model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tcn_10 (TCN)                 multiple                  136256
# _________________________________________________________________
# tcn_11 (TCN)                 multiple                  136256
# _________________________________________________________________
# concatenate_5 (Concatenate)  multiple                  0
# _________________________________________________________________
# attention_layer_5 (Attention multiple                  16512
# _________________________________________________________________
# reshape_5 (Reshape)          multiple                  0
# _________________________________________________________________
# dense_5 (Dense)              multiple                  14
# =================================================================
# Total params: 289,038
# Trainable params: 289,038
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 模型结构可视化
plot_model(model_mushroom, show_shapes=True, show_layer_names=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
# Early Stopping 设置
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

Training_history = []
for model_index in range(len(model_list)):
    Test_dic = Data_process_defore_train(Target_frame_train_list_slided_normalized[model_index])
    history = model_list[model_index].fit([Test_dic["X1训练集"], Test_dic["X2训练集"]], Test_dic["Y训练集"],
                    epochs=100,
                    batch_size=32,
                    validation_data=([Test_dic["X1验证集"], Test_dic["X2验证集"]], Test_dic["Y验证集"]),
                    callbacks=[early_stopping])
    # 使用测试集评估模型
    test_loss = model_list[model_index].evaluate([Test_dic["X1测试集"], Test_dic["X2测试集"]], Test_dic["Y测试集"])
    print(f"Test loss: {test_loss}")
    Training_history.append(history)
# Out:
# Training set: (639, 2) (639,)
# Validation set: (212, 2) (212,)
# Test set: (212, 2) (212,)
# Epoch 1/100
# 20/20 [==============================] - 5s 79ms/step - loss: 0.7499 - val_loss: 0.2630
# Epoch 2/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2827 - val_loss: 0.2533
# Epoch 3/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.2722 - val_loss: 0.2443
# Epoch 4/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2624 - val_loss: 0.2350
# Epoch 5/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2532 - val_loss: 0.2260
# Epoch 6/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2442 - val_loss: 0.2188
# Epoch 7/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2356 - val_loss: 0.2099
# Epoch 8/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2277 - val_loss: 0.2025
# Epoch 9/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2200 - val_loss: 0.1960
# Epoch 10/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2132 - val_loss: 0.1892
# Epoch 11/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.2066 - val_loss: 0.1832
# Epoch 12/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2004 - val_loss: 0.1775
# Epoch 13/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1950 - val_loss: 0.1724
# Epoch 14/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1897 - val_loss: 0.1678
# Epoch 15/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1849 - val_loss: 0.1637
# Epoch 16/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1806 - val_loss: 0.1597
# Epoch 17/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1768 - val_loss: 0.1566
# Epoch 18/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1730 - val_loss: 0.1527
# Epoch 19/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1696 - val_loss: 0.1506
# Epoch 20/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1667 - val_loss: 0.1468
# Epoch 21/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1638 - val_loss: 0.1444
# Epoch 22/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1615 - val_loss: 0.1429
# Epoch 23/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1594 - val_loss: 0.1402
# Epoch 24/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1572 - val_loss: 0.1389
# Epoch 25/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1552 - val_loss: 0.1364
# Epoch 26/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1538 - val_loss: 0.1349
# Epoch 27/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1522 - val_loss: 0.1349
# Epoch 28/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1506 - val_loss: 0.1323
# Epoch 29/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1492 - val_loss: 0.1315
# Epoch 30/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1481 - val_loss: 0.1305
# Epoch 31/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1471 - val_loss: 0.1296
# Epoch 32/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1462 - val_loss: 0.1288
# Epoch 33/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1454 - val_loss: 0.1280
# Epoch 34/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1451 - val_loss: 0.1272
# Epoch 35/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1443 - val_loss: 0.1269
# Epoch 36/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1435 - val_loss: 0.1265
# Epoch 37/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1432 - val_loss: 0.1258
# Epoch 38/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1425 - val_loss: 0.1256
# Epoch 39/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1422 - val_loss: 0.1253
# Epoch 40/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1419 - val_loss: 0.1248
# Epoch 41/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1416 - val_loss: 0.1245
# Epoch 42/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1412 - val_loss: 0.1248
# Epoch 43/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1410 - val_loss: 0.1240
# Epoch 44/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1407 - val_loss: 0.1241
# Epoch 45/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1405 - val_loss: 0.1238
# Epoch 46/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1405 - val_loss: 0.1236
# Epoch 47/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1403 - val_loss: 0.1236
# Epoch 48/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1401 - val_loss: 0.1235
# Epoch 49/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1400 - val_loss: 0.1236
# Epoch 50/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1400 - val_loss: 0.1237
# Epoch 51/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1399 - val_loss: 0.1234
# Epoch 52/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.1397 - val_loss: 0.1232
# Epoch 53/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1397 - val_loss: 0.1233
# Epoch 54/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1399 - val_loss: 0.1243
# Epoch 55/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1397 - val_loss: 0.1230
# Epoch 56/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1398 - val_loss: 0.1233
# Epoch 57/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1395 - val_loss: 0.1233
# Epoch 58/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1395 - val_loss: 0.1235
# Epoch 59/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1395 - val_loss: 0.1229
# Epoch 60/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1395 - val_loss: 0.1233
# Epoch 61/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1395 - val_loss: 0.1231
# Epoch 62/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1395 - val_loss: 0.1232
# Epoch 63/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1394 - val_loss: 0.1229
# Epoch 64/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1394 - val_loss: 0.1235
# Epoch 65/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1397 - val_loss: 0.1230
# Epoch 66/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1394 - val_loss: 0.1231
# Epoch 67/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1394 - val_loss: 0.1230
# Epoch 68/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1394 - val_loss: 0.1234
# Epoch 69/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1393 - val_loss: 0.1230
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1281
# Test loss: 0.128061905503273
# Training set: (639, 2) (639,)
# Validation set: (212, 2) (212,)
# Test set: (212, 2) (212,)
# Epoch 1/100
# 20/20 [==============================] - 4s 76ms/step - loss: 0.9839 - val_loss: 0.3852
# Epoch 2/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.3785 - val_loss: 0.3494
# Epoch 3/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.3528 - val_loss: 0.3300
# Epoch 4/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.3347 - val_loss: 0.3138
# Epoch 5/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.3185 - val_loss: 0.2987
# Epoch 6/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.3035 - val_loss: 0.2849
# Epoch 7/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2896 - val_loss: 0.2721
# Epoch 8/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2766 - val_loss: 0.2600
# Epoch 9/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2644 - val_loss: 0.2486
# Epoch 10/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2529 - val_loss: 0.2380
# Epoch 11/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2421 - val_loss: 0.2281
# Epoch 12/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2321 - val_loss: 0.2189
# Epoch 13/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2226 - val_loss: 0.2102
# Epoch 14/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2138 - val_loss: 0.2022
# Epoch 15/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2056 - val_loss: 0.1947
# Epoch 16/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1980 - val_loss: 0.1879
# Epoch 17/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1910 - val_loss: 0.1815
# Epoch 18/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1844 - val_loss: 0.1757
# Epoch 19/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1785 - val_loss: 0.1702
# Epoch 20/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1729 - val_loss: 0.1653
# Epoch 21/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1678 - val_loss: 0.1608
# Epoch 22/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1631 - val_loss: 0.1567
# Epoch 23/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1589 - val_loss: 0.1530
# Epoch 24/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1550 - val_loss: 0.1496
# Epoch 25/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.1514 - val_loss: 0.1465
# Epoch 26/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1482 - val_loss: 0.1437
# Epoch 27/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1452 - val_loss: 0.1412
# Epoch 28/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.1426 - val_loss: 0.1390
# Epoch 29/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1401 - val_loss: 0.1370
# Epoch 30/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1380 - val_loss: 0.1351
# Epoch 31/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1361 - val_loss: 0.1335
# Epoch 32/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1343 - val_loss: 0.1321
# Epoch 33/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1327 - val_loss: 0.1308
# Epoch 34/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1313 - val_loss: 0.1297
# Epoch 35/100
# 20/20 [==============================] - 1s 49ms/step - loss: 0.1301 - val_loss: 0.1288
# Epoch 36/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1290 - val_loss: 0.1279
# Epoch 37/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1280 - val_loss: 0.1271
# Epoch 38/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1271 - val_loss: 0.1265
# Epoch 39/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1263 - val_loss: 0.1259
# Epoch 40/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1256 - val_loss: 0.1254
# Epoch 41/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1250 - val_loss: 0.1250
# Epoch 42/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1245 - val_loss: 0.1246
# Epoch 43/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1241 - val_loss: 0.1243
# Epoch 44/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.1237 - val_loss: 0.1241
# Epoch 45/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1233 - val_loss: 0.1239
# Epoch 46/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1230 - val_loss: 0.1237
# Epoch 47/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1227 - val_loss: 0.1235
# Epoch 48/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1225 - val_loss: 0.1234
# Epoch 49/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1223 - val_loss: 0.1233
# Epoch 50/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1221 - val_loss: 0.1232
# Epoch 51/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1220 - val_loss: 0.1231
# Epoch 52/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1219 - val_loss: 0.1231
# Epoch 53/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1217 - val_loss: 0.1230
# Epoch 54/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1216 - val_loss: 0.1230
# Epoch 55/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1216 - val_loss: 0.1230
# Epoch 56/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1215 - val_loss: 0.1230
# Epoch 57/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1214 - val_loss: 0.1230
# Epoch 58/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1214 - val_loss: 0.1229
# Epoch 59/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1213 - val_loss: 0.1229
# Epoch 60/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1213 - val_loss: 0.1230
# Epoch 61/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1213 - val_loss: 0.1229
# Epoch 62/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1213 - val_loss: 0.1230
# Epoch 63/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1212 - val_loss: 0.1230
# Epoch 64/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1212 - val_loss: 0.1230
# Epoch 65/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1212 - val_loss: 0.1230
# Epoch 66/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.1212 - val_loss: 0.1230
# Epoch 67/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1212 - val_loss: 0.1230
# Epoch 68/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1212 - val_loss: 0.1230
# Epoch 69/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1212 - val_loss: 0.1230
# Epoch 70/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1212 - val_loss: 0.1230
# Epoch 71/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1212 - val_loss: 0.1230
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1193
# Test loss: 0.11934549361467361
# Training set: (632, 2) (632,)
# Validation set: (210, 2) (210,)
# Test set: (210, 2) (210,)
# Epoch 1/100
# 20/20 [==============================] - 4s 76ms/step - loss: 0.7976 - val_loss: 0.2880
# Epoch 2/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.3090 - val_loss: 0.2798
# Epoch 3/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2980 - val_loss: 0.2708
# Epoch 4/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2872 - val_loss: 0.2593
# Epoch 5/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2762 - val_loss: 0.2489
# Epoch 6/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2660 - val_loss: 0.2394
# Epoch 7/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2561 - val_loss: 0.2334
# Epoch 8/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2468 - val_loss: 0.2238
# Epoch 9/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2380 - val_loss: 0.2164
# Epoch 10/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2299 - val_loss: 0.2096
# Epoch 11/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2224 - val_loss: 0.2041
# Epoch 12/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2153 - val_loss: 0.1956
# Epoch 13/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2086 - val_loss: 0.1896
# Epoch 14/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2024 - val_loss: 0.1856
# Epoch 15/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1968 - val_loss: 0.1798
# Epoch 16/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1913 - val_loss: 0.1760
# Epoch 17/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1865 - val_loss: 0.1728
# Epoch 18/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1819 - val_loss: 0.1688
# Epoch 19/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1777 - val_loss: 0.1650
# Epoch 20/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1738 - val_loss: 0.1627
# Epoch 21/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1703 - val_loss: 0.1587
# Epoch 22/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1669 - val_loss: 0.1562
# Epoch 23/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1639 - val_loss: 0.1540
# Epoch 24/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1612 - val_loss: 0.1506
# Epoch 25/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1587 - val_loss: 0.1487
# Epoch 26/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1562 - val_loss: 0.1483
# Epoch 27/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1540 - val_loss: 0.1448
# Epoch 28/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1521 - val_loss: 0.1447
# Epoch 29/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1503 - val_loss: 0.1425
# Epoch 30/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1485 - val_loss: 0.1419
# Epoch 31/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1470 - val_loss: 0.1402
# Epoch 32/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1457 - val_loss: 0.1397
# Epoch 33/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1444 - val_loss: 0.1381
# Epoch 34/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1433 - val_loss: 0.1380
# Epoch 35/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1421 - val_loss: 0.1370
# Epoch 36/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1411 - val_loss: 0.1363
# Epoch 37/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1403 - val_loss: 0.1355
# Epoch 38/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1396 - val_loss: 0.1351
# Epoch 39/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1388 - val_loss: 0.1353
# Epoch 40/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1382 - val_loss: 0.1345
# Epoch 41/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1375 - val_loss: 0.1343
# Epoch 42/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1370 - val_loss: 0.1337
# Epoch 43/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1365 - val_loss: 0.1332
# Epoch 44/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1361 - val_loss: 0.1334
# Epoch 45/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1357 - val_loss: 0.1336
# Epoch 46/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1354 - val_loss: 0.1327
# Epoch 47/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1350 - val_loss: 0.1329
# Epoch 48/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1348 - val_loss: 0.1327
# Epoch 49/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1345 - val_loss: 0.1327
# Epoch 50/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1343 - val_loss: 0.1327
# Epoch 51/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1341 - val_loss: 0.1324
# Epoch 52/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1339 - val_loss: 0.1324
# Epoch 53/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1338 - val_loss: 0.1324
# Epoch 54/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1337 - val_loss: 0.1321
# Epoch 55/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1335 - val_loss: 0.1322
# Epoch 56/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1334 - val_loss: 0.1325
# Epoch 57/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1333 - val_loss: 0.1324
# Epoch 58/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1332 - val_loss: 0.1322
# Epoch 59/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1332 - val_loss: 0.1327
# Epoch 60/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1331 - val_loss: 0.1321
# Epoch 61/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1330 - val_loss: 0.1326
# Epoch 62/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1330 - val_loss: 0.1322
# Epoch 63/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1331 - val_loss: 0.1326
# Epoch 64/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1329 - val_loss: 0.1321
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1286
# Test loss: 0.12860359251499176
# Training set: (618, 2) (618,)
# Validation set: (205, 2) (205,)
# Test set: (205, 2) (205,)
# Epoch 1/100
# 20/20 [==============================] - 4s 75ms/step - loss: 1.3102 - val_loss: 0.4240
# Epoch 2/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.3973 - val_loss: 0.3712
# Epoch 3/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.3601 - val_loss: 0.3466
# Epoch 4/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.3389 - val_loss: 0.3292
# Epoch 5/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.3219 - val_loss: 0.3138
# Epoch 6/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.3066 - val_loss: 0.2996
# Epoch 7/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2925 - val_loss: 0.2862
# Epoch 8/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2793 - val_loss: 0.2740
# Epoch 9/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2672 - val_loss: 0.2627
# Epoch 10/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2560 - val_loss: 0.2519
# Epoch 11/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2454 - val_loss: 0.2420
# Epoch 12/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2355 - val_loss: 0.2326
# Epoch 13/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2262 - val_loss: 0.2238
# Epoch 14/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2176 - val_loss: 0.2158
# Epoch 15/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2096 - val_loss: 0.2082
# Epoch 16/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2022 - val_loss: 0.2012
# Epoch 17/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1953 - val_loss: 0.1948
# Epoch 18/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1889 - val_loss: 0.1888
# Epoch 19/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1830 - val_loss: 0.1832
# Epoch 20/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1775 - val_loss: 0.1781
# Epoch 21/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1724 - val_loss: 0.1734
# Epoch 22/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1678 - val_loss: 0.1691
# Epoch 23/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1635 - val_loss: 0.1652
# Epoch 24/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1595 - val_loss: 0.1616
# Epoch 25/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1559 - val_loss: 0.1583
# Epoch 26/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1526 - val_loss: 0.1552
# Epoch 27/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1496 - val_loss: 0.1525
# Epoch 28/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1469 - val_loss: 0.1501
# Epoch 29/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1443 - val_loss: 0.1479
# Epoch 30/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1421 - val_loss: 0.1459
# Epoch 31/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1401 - val_loss: 0.1441
# Epoch 32/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1383 - val_loss: 0.1425
# Epoch 33/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1366 - val_loss: 0.1411
# Epoch 34/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1352 - val_loss: 0.1398
# Epoch 35/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1338 - val_loss: 0.1387
# Epoch 36/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1326 - val_loss: 0.1377
# Epoch 37/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1315 - val_loss: 0.1368
# Epoch 38/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1306 - val_loss: 0.1360
# Epoch 39/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1298 - val_loss: 0.1353
# Epoch 40/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1290 - val_loss: 0.1347
# Epoch 41/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1283 - val_loss: 0.1343
# Epoch 42/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1277 - val_loss: 0.1338
# Epoch 43/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1272 - val_loss: 0.1333
# Epoch 44/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1267 - val_loss: 0.1330
# Epoch 45/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.1263 - val_loss: 0.1327
# Epoch 46/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1260 - val_loss: 0.1324
# Epoch 47/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1256 - val_loss: 0.1323
# Epoch 48/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1253 - val_loss: 0.1321
# Epoch 49/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1251 - val_loss: 0.1320
# Epoch 50/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1249 - val_loss: 0.1318
# Epoch 51/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1247 - val_loss: 0.1317
# Epoch 52/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1245 - val_loss: 0.1317
# Epoch 53/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1244 - val_loss: 0.1317
# Epoch 54/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.1243 - val_loss: 0.1315
# Epoch 55/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1242 - val_loss: 0.1316
# Epoch 56/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1241 - val_loss: 0.1315
# Epoch 57/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1240 - val_loss: 0.1315
# Epoch 58/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1239 - val_loss: 0.1314
# Epoch 59/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1239 - val_loss: 0.1314
# Epoch 60/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1238 - val_loss: 0.1314
# Epoch 61/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1238 - val_loss: 0.1315
# Epoch 62/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1237 - val_loss: 0.1315
# Epoch 63/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1237 - val_loss: 0.1315
# Epoch 64/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1237 - val_loss: 0.1315
# Epoch 65/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1236 - val_loss: 0.1315
# Epoch 66/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1236 - val_loss: 0.1315
# Epoch 67/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1236 - val_loss: 0.1315
# Epoch 68/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1236 - val_loss: 0.1316
# Epoch 69/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1236 - val_loss: 0.1315
# Epoch 70/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.1236 - val_loss: 0.1315
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1352
# Test loss: 0.13524805009365082
# Training set: (639, 2) (639,)
# Validation set: (212, 2) (212,)
# Test set: (212, 2) (212,)
# Epoch 1/100
# 20/20 [==============================] - 4s 76ms/step - loss: 1.1615 - val_loss: 0.3579
# Epoch 2/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.3370 - val_loss: 0.3468
# Epoch 3/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.3256 - val_loss: 0.3358
# Epoch 4/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.3145 - val_loss: 0.3236
# Epoch 5/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.3031 - val_loss: 0.3116
# Epoch 6/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2916 - val_loss: 0.2997
# Epoch 7/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2805 - val_loss: 0.2883
# Epoch 8/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2697 - val_loss: 0.2769
# Epoch 9/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2592 - val_loss: 0.2661
# Epoch 10/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2493 - val_loss: 0.2558
# Epoch 11/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2398 - val_loss: 0.2461
# Epoch 12/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2308 - val_loss: 0.2367
# Epoch 13/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2223 - val_loss: 0.2280
# Epoch 14/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2143 - val_loss: 0.2198
# Epoch 15/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2069 - val_loss: 0.2119
# Epoch 16/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1998 - val_loss: 0.2049
# Epoch 17/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1933 - val_loss: 0.1979
# Epoch 18/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1872 - val_loss: 0.1917
# Epoch 19/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1816 - val_loss: 0.1858
# Epoch 20/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1763 - val_loss: 0.1803
# Epoch 21/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1715 - val_loss: 0.1752
# Epoch 22/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1670 - val_loss: 0.1706
# Epoch 23/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1629 - val_loss: 0.1660
# Epoch 24/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1590 - val_loss: 0.1622
# Epoch 25/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1556 - val_loss: 0.1585
# Epoch 26/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1525 - val_loss: 0.1551
# Epoch 27/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1496 - val_loss: 0.1520
# Epoch 28/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1469 - val_loss: 0.1491
# Epoch 29/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1446 - val_loss: 0.1466
# Epoch 30/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1424 - val_loss: 0.1443
# Epoch 31/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1404 - val_loss: 0.1421
# Epoch 32/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1386 - val_loss: 0.1401
# Epoch 33/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1370 - val_loss: 0.1383
# Epoch 34/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1356 - val_loss: 0.1367
# Epoch 35/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1343 - val_loss: 0.1353
# Epoch 36/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1331 - val_loss: 0.1340
# Epoch 37/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1321 - val_loss: 0.1328
# Epoch 38/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1312 - val_loss: 0.1318
# Epoch 39/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1304 - val_loss: 0.1307
# Epoch 40/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1297 - val_loss: 0.1299
# Epoch 41/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1290 - val_loss: 0.1291
# Epoch 42/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1285 - val_loss: 0.1284
# Epoch 43/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1280 - val_loss: 0.1279
# Epoch 44/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1276 - val_loss: 0.1273
# Epoch 45/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1272 - val_loss: 0.1268
# Epoch 46/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1268 - val_loss: 0.1264
# Epoch 47/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1266 - val_loss: 0.1260
# Epoch 48/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1263 - val_loss: 0.1256
# Epoch 49/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1261 - val_loss: 0.1253
# Epoch 50/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1259 - val_loss: 0.1252
# Epoch 51/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1257 - val_loss: 0.1248
# Epoch 52/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1256 - val_loss: 0.1247
# Epoch 53/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1255 - val_loss: 0.1245
# Epoch 54/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1253 - val_loss: 0.1243
# Epoch 55/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.1253 - val_loss: 0.1240
# Epoch 56/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1252 - val_loss: 0.1240
# Epoch 57/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1251 - val_loss: 0.1239
# Epoch 58/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1251 - val_loss: 0.1238
# Epoch 59/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1250 - val_loss: 0.1238
# Epoch 60/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1250 - val_loss: 0.1237
# Epoch 61/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1249 - val_loss: 0.1235
# Epoch 62/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1249 - val_loss: 0.1235
# Epoch 63/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1249 - val_loss: 0.1234
# Epoch 64/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1249 - val_loss: 0.1233
# Epoch 65/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1249 - val_loss: 0.1232
# Epoch 66/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1249 - val_loss: 0.1233
# Epoch 67/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1232
# Epoch 68/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1233
# Epoch 69/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1232
# Epoch 70/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 71/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 72/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 73/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 74/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1232
# Epoch 75/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 76/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 77/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1230
# Epoch 78/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1230
# Epoch 79/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1230
# Epoch 80/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 81/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1229
# Epoch 82/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1230
# Epoch 83/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 84/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 85/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1230
# Epoch 86/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1230
# Epoch 87/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1229
# Epoch 88/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1230
# Epoch 89/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1229
# Epoch 90/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 91/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1230
# Epoch 92/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1230
# Epoch 93/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1230
# Epoch 94/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1229
# Epoch 95/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1230
# Epoch 96/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1231
# Epoch 97/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1248 - val_loss: 0.1229
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1293
# Test loss: 0.12933559715747833
# Training set: (639, 2) (639,)
# Validation set: (212, 2) (212,)
# Test set: (212, 2) (212,)
# Epoch 1/100
# 20/20 [==============================] - 1s 47ms/step - loss: 0.1209 - val_loss: 0.1206
# Epoch 2/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1203 - val_loss: 0.1186
# Epoch 3/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1200 - val_loss: 0.1200
# Epoch 4/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1200 - val_loss: 0.1196
# Epoch 5/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1201 - val_loss: 0.1203
# Epoch 6/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1200 - val_loss: 0.1186
# Epoch 7/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1200 - val_loss: 0.1197
# Epoch 8/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1198 - val_loss: 0.1191
# Epoch 9/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1198 - val_loss: 0.1198
# Epoch 10/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1198 - val_loss: 0.1197
# Epoch 11/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1198 - val_loss: 0.1195
# Epoch 12/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1199 - val_loss: 0.1198
# Epoch 13/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1199 - val_loss: 0.1188
# Epoch 14/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1198 - val_loss: 0.1197
# Epoch 15/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.1198 - val_loss: 0.1203
# Epoch 16/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.1198 - val_loss: 0.1188
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1264
# Test loss: 0.12638774514198303

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# 遍历所有的模型并绘制
for i, history in enumerate(Training_history):
    row = i // 3
    col = i % 3
    ax = axes[row, col]
    
    # 绘制训练集和验证集的准确度/损失值
    ax.plot(history.history['loss'], label='Training Loss')
    ax.plot(history.history['val_loss'], label='Validation Loss')
    
    # 添加标题和标签
    ax.set_title(f'Model {i+1} Loss')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Loss')
    ax.legend()

# 展示图表
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 预测模型
#
# - 我们已经对于六个品类分别训练了对应的神经网络模型，现在我们需要基于这个模型进行数据预测
# - 根据前面的归一化模型进行反归一化
# - 模型顺序为：'水生根茎类', '花叶类', '花菜类', '茄类', '辣椒类', '食用菌'

# %%
# 获取未来七天的二十四节气编码
last_date_in_index = Target_frame_train_list[0].index[-1] 
last_date = pd.Timestamp(last_date_in_index) 

future_7_days = pd.date_range(start=last_date, periods=8, freq='D')[1:]
future_7_days
# Out:
# DatetimeIndex(['2023-07-01', '2023-07-02', '2023-07-03', '2023-07-04',
#                '2023-07-05', '2023-07-06', '2023-07-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
solor_tern_7day_future = pd.DataFrame()
solor_tern_7day_future = future_7_days.map(lambda x: encode_solar_term(x.month, x.day))
solor_tern_7day_future = pd.DataFrame(solor_tern_7day_future)
solor_tern_7day_future.columns = ['未来七天节气']
X2_predict = deal_X2(solor_tern_7day_future)

# %%
def predict_cost(num):
    Root_stock_prediction = pd.DataFrame()
    last_15_data_root_Stock = Target_frame_train_list_slided_normalized[num].iloc[-1:, 2]
    row_data = {
                '过去时间窗口成本': list(last_15_data_root_Stock.values),
                '未来七天节气': X2_predict 
            }
    Root_stock_prediction = Root_stock_prediction.append(row_data, ignore_index=True)
    X1 = np.array(list(Root_stock_prediction["过去时间窗口成本"])).reshape(-1,15,1)
    prediction_root_stock_finish = model_list[num].predict([X1, X1])
    scaler1 = MinMaxScaler()
    scaled_array = scaler1.fit_transform(Target_frame_train_list[num].iloc[:,2].values.reshape(-1, 1))
    inverse_scaled_array = scaler1.inverse_transform(prediction_root_stock_finish.reshape(-1, 1))
    
    return inverse_scaled_array

# %%
Data_predicted_result = pd.DataFrame()
for i in range(6):
    a = predict_cost(i).reshape(1,-1)
    Data_predicted_result[name_type_list[i]] = a[0]
Data_predicted_result_new_index = pd.date_range(start='2023-07-01', periods=len(Data_predicted_result), freq='D')
Data_predicted_result.index = Data_predicted_result_new_index

Data_predicted_result
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f497f15eae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#                 水生根茎类       花叶类       花菜类        茄类        辣椒类       食用菌
# 2023-07-01  12.194471  3.597822  7.902676  6.303248  16.629280  6.298101
# 2023-07-02  12.848233  4.549907  4.909533  6.901423  16.460171  6.667544
# 2023-07-03  14.759225  5.178307  8.044641  5.522075   7.235115  7.778035
# 2023-07-04  14.921809  3.491119  8.111454  7.972598  16.127409  7.877094
# 2023-07-05  14.975589  3.667404  8.254215  5.644081   8.223042  7.905783
# 2023-07-06  14.064912  4.316905  8.836736  7.305111  16.623854  7.367867
# 2023-07-07  14.899441  2.507610  9.045962  5.957997   6.847824  7.860124

# %% [markdown]
# ### 最优化决策模型

# %% [markdown]
# #### 我们需要对其可能的销量进行数学建模，构造一个置信区间用来给销量添加范围限制

# %%
DataFrame_list_type_fillted = {}

for name in name_type_list:
    temp_frame = Profit_wighted_stat[Profit_wighted_stat['品类名称'] == name]["销售量之和"]
    DataFrame_list_type_fillted[name] = temp_frame

# %%
# 定义滑动窗口函数
def slide_window_prepare_data(df, window_size):
    # 初始化一个空的DataFrame来存储结果
    result_df = pd.DataFrame(columns=['过去时间窗口销量', '未来七天销量'])

    for i in range(len(df) - window_size - 6):  # 留出空间以预测未来7天的销售量
        past_window_data = df.iloc[i:i + window_size].tolist()  # 获取window_size大小的窗口数据并转为列表
        future_7_days_data = df.iloc[i + window_size:i + window_size + 7].tolist()  # 获取未来7天的数据并转为列表
        result_df.loc[i] = [past_window_data, future_7_days_data]
            
    return result_df

# %%
def MinMaxScaler_type_sale_prediction(df):
    # 初始化归一化器
    scaler = MinMaxScaler()

    # 提取列并转换为适合归一化的格式
    past_sales_list = np.array(result_df['过去时间窗口销量'].tolist())
    future_sales_list = np.array(result_df['未来七天销量'].tolist())

    # 归一化
    past_sales_list_scaled = scaler.fit_transform(past_sales_list)
    future_sales_list_scaled = scaler.fit_transform(future_sales_list)
    df = pd.DataFrame()
    # 将归一化后的数据转换回DataFrame的原始格式
    df['过去时间窗口销量'] = past_sales_list_scaled.tolist()
    df['未来七天销量'] = future_sales_list_scaled.tolist()
    return df

# %%
DataFrame_list_type_fillted_normalized = {}
for name in name_type_list:
    window_size = 7  # 可以设置为你需要的窗口大小
    result_df = slide_window_prepare_data(DataFrame_list_type_fillted[name], window_size)
    result_df = MinMaxScaler_type_sale_prediction(result_df)
    DataFrame_list_type_fillted_normalized[name] = result_df

# %%
def Data_process_defore_train_tepe_sale(Dataframe):
    # 获取数据集总长度
    n = len(Dataframe)
    # 计算测试集、验证集和训练集的大小
    test_size = int(n * 0.2)
    val_size = int(n * 0.8 * 0.25)
    train_size = n - test_size - val_size

    # 分离自变量和因变量
    X = Dataframe["过去时间窗口销量"]
    y = Dataframe["未来七天销量"]

    # 按照顺序切分数据集
    X_train = X.iloc[:train_size]
    y_train = y.iloc[:train_size]

    X_val = X.iloc[train_size:train_size+val_size]
    y_val = y.iloc[train_size:train_size+val_size]

    X_test = X.iloc[train_size+val_size:]
    y_test = y.iloc[train_size+val_size:]

    # 打印各个数据集的大小
    print("Training set:", X_train.shape, y_train.shape)
    print("Validation set:", X_val.shape, y_val.shape)
    print("Test set:", X_test.shape, y_test.shape)
    # 确保X_train, y_train, X_val, y_val, X_test, y_test都已正确加载并预处理
    X1_train = df_to_nparray(X_train).reshape(-1, 7, 1)
    y_train_array = df_to_nparray(y_train).reshape(-1, 7)

    X1_val = df_to_nparray(X_val).reshape(-1, 7, 1)

    y_val_array = df_to_nparray(y_val).reshape(-1, 7)

    X1_test = df_to_nparray(X_test).reshape(-1, 7, 1)

    y_test_array = df_to_nparray(y_test).reshape(-1, 7)
    return {"X训练集":X1_train,
            "X验证集":X1_val,
            "X测试集":X1_test,
            "Y训练集":y_train_array,
            "Y验证集":y_val_array,
            "Y测试集":y_test_array}

# %%
DataFrame_list_type_fillted_normalized_train_split = {}
for name in name_type_list:
    DataFrame_list_type_fillted_normalized_train_split[name] = Data_process_defore_train_tepe_sale(DataFrame_list_type_fillted_normalized[name])
# Out:
# Training set: (644,) (644,)
# Validation set: (214,) (214,)
# Test set: (214,) (214,)
# Training set: (644,) (644,)
# Validation set: (214,) (214,)
# Test set: (214,) (214,)
# Training set: (637,) (637,)
# Validation set: (212,) (212,)
# Test set: (212,) (212,)
# Training set: (623,) (623,)
# Validation set: (207,) (207,)
# Test set: (207,) (207,)
# Training set: (644,) (644,)
# Validation set: (214,) (214,)
# Test set: (214,) (214,)
# Training set: (644,) (644,)
# Validation set: (214,) (214,)
# Test set: (214,) (214,)

# %%
# 搭建模型
class AttentionLayer(tf.keras.layers.Layer):
    def __init__(self, units):
        super(AttentionLayer, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, values, query):
        query_with_time_axis = tf.expand_dims(query, 1)
        score = self.V(tf.nn.tanh(self.W1(query_with_time_axis) + self.W2(values)))
        attention_weights = tf.nn.softmax(score, axis=1)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)
        return context_vector, attention_weights

class AttentionTCNModel:
    def __init__(self, input_shape, output_shape):
        self.input_shape = input_shape
        self.output_shape = output_shape
        self.model = self.build_model()

    def build_model(self):
        input_layer = Input(shape=self.input_shape)

        # TCN 层
        tcn_output = TCN(input_shape=self.input_shape)(input_layer)

        # 注意力层
        context_vector, attention_weights = AttentionLayer(units=128)(tcn_output, tcn_output)

        # 全连接层
        output_layer = Dense(64, activation='relu')(context_vector)
        output_layer = Dense(self.output_shape[1], activation='linear')(output_layer)

        # 构建模型
        model = Model(inputs=input_layer, outputs=output_layer)

        # 编译模型
        model.compile(optimizer='adam', loss='mse')

        return model

    def summary(self):
        self.model.summary()

# 使用
input_shape = (7, 1)
output_shape = (644, 7)  # 注意：这里我们只用输出维度的第二个数字，因为第一个数字（644）是batch_size，它在模型定义时不是必需的。

my_model = AttentionTCNModel(input_shape, output_shape)
my_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 7, 1)]       0
# __________________________________________________________________________________________________
# tcn_12 (TCN)                    (None, 64)           136256      input_1[0][0]
# __________________________________________________________________________________________________
# attention_layer_6 (AttentionLay ((None, 64), (None,  16769       tcn_12[0][0]
#                                                                  tcn_12[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           4160        attention_layer_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 7)            455         dense_9[0][0]
# ==================================================================================================
# Total params: 157,640
# Trainable params: 157,640
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
History_model_sampling = {}
Model_diction_sampling = {}
# 自动化训练模型

for name in name_type_list:
    temp_model_list = []
    temp_history_list = []
    x_train = DataFrame_list_type_fillted_normalized_train_split[name]["X训练集"]
    y_train = DataFrame_list_type_fillted_normalized_train_split[name]["Y训练集"]
    x_val = DataFrame_list_type_fillted_normalized_train_split[name]["X验证集"]
    y_val = DataFrame_list_type_fillted_normalized_train_split[name]["Y验证集"]
    x_test = DataFrame_list_type_fillted_normalized_train_split[name]["X测试集"]
    y_test = DataFrame_list_type_fillted_normalized_train_split[name]["Y测试集"]
    input_shape = (7, 1)
    output_shape = (644, 7)
    for tims in range(60):
        my_model = AttentionTCNModel(input_shape, output_shape)
        history = my_model.model.fit(x_train, y_train, epochs=100, batch_size=32,
                                     validation_data=(x_val, y_val), callbacks=[early_stopping])
        test_loss = my_model.model.evaluate(x_test, y_test)
        print(name," 模型的",f"测试损失是 : {test_loss}")
        temp_model_list.append(my_model)
        temp_history_list.append(history)
    History_model_sampling[name] = temp_history_list
    Model_diction_sampling[name] = temp_model_list
# Out:
# Epoch 1/100
# 21/21 [==============================] - 2s 34ms/step - loss: 0.0226 - val_loss: 0.0208
# Epoch 2/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0101 - val_loss: 0.0130
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0177
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0222
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0446
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0417
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0118
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0248
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0467
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0232
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0533
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0627
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0475
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0465
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0422
# Epoch 16/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0473
# Epoch 17/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0205
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0081
# 水生根茎类  模型的 测试损失是 : 0.008092890493571758
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0199 - val_loss: 0.0537
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0359
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0121 - val_loss: 0.0275
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0219
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0366
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0246
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0420
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0299
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0600
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0484
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0374
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0074 - val_loss: 0.0386
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0483
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0531
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0158
# 水生根茎类  模型的 测试损失是 : 0.015772759914398193
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0138 - val_loss: 0.0207
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0483
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0170
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0361
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0428
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0224
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0123
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0187
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0247
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0202
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0200
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0197
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0245
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0236
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0171
# Epoch 16/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 0.0247
# Epoch 17/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0265
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0081
# 水生根茎类  模型的 测试损失是 : 0.008136817254126072
# Epoch 1/100
# 21/21 [==============================] - 3s 33ms/step - loss: 0.0117 - val_loss: 0.0161
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0169
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0388
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0211
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0526
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0230
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0278
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0272
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0264
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0296
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0386
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0116
# 水生根茎类  模型的 测试损失是 : 0.011629302985966206
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0184 - val_loss: 0.0240
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0444
# Epoch 3/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0083 - val_loss: 0.0317
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0185
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0131 - val_loss: 0.0218
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0236
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0354
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0596
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0575
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0408
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0469
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0566
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0543
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0484
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0118
# 水生根茎类  模型的 测试损失是 : 0.011788741685450077
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0169 - val_loss: 0.0215
# Epoch 2/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0087 - val_loss: 0.0326
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0593
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0341
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0192
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0303
# Epoch 7/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0065 - val_loss: 0.0286
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0423
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0363
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0182
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0093 - val_loss: 0.0213
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0170
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0358
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0425
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0286
# Epoch 16/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0341
# Epoch 17/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0237
# Epoch 18/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0216
# Epoch 19/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0255
# Epoch 20/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0210
# Epoch 21/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0309
# Epoch 22/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0236
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0114
# 水生根茎类  模型的 测试损失是 : 0.011418008245527744
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0357 - val_loss: 0.0167
# Epoch 2/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0090 - val_loss: 0.0200
# Epoch 3/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0085 - val_loss: 0.0299
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0430
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0509
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0663
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0565
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0644
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0628
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0400
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0465
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0122
# 水生根茎类  模型的 测试损失是 : 0.012186244130134583
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0213 - val_loss: 0.0158
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0405
# Epoch 3/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0083 - val_loss: 0.0314
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0113 - val_loss: 0.0201
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0144
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0105 - val_loss: 0.0121
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0231
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0294
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0284
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0248
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0259
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0285
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0289
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0253
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0215
# Epoch 16/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0184
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0110
# 水生根茎类  模型的 测试损失是 : 0.011008723638951778
# Epoch 1/100
# 21/21 [==============================] - 2s 32ms/step - loss: 0.0311 - val_loss: 0.0244
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0206
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0356
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0294
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0336
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0519
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0155
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0113 - val_loss: 0.0243
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0229
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0228
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0359
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0442
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0343
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0333
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0340
# Epoch 16/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0326
# Epoch 17/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0355
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0094
# 水生根茎类  模型的 测试损失是 : 0.00937765184789896
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0621 - val_loss: 0.0214
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0095 - val_loss: 0.0161
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0186
# Epoch 4/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0087 - val_loss: 0.0145
# Epoch 5/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0088 - val_loss: 0.0156
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0204
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0137
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0178
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0333
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0074 - val_loss: 0.0215
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0278
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0192
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0279
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0321
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0210
# Epoch 16/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0357
# Epoch 17/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0428
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0096
# 水生根茎类  模型的 测试损失是 : 0.009614018723368645
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0126 - val_loss: 0.0135
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0194
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0364
# Epoch 4/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0072 - val_loss: 0.0694
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0614
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0174
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0121 - val_loss: 0.0121
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0120
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0146
# Epoch 10/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0067 - val_loss: 0.0195
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0245
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0166
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0247
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0234
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0240
# Epoch 16/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0287
# Epoch 17/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0317
# Epoch 18/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 0.0254
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0089
# 水生根茎类  模型的 测试损失是 : 0.008900468237698078
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0116 - val_loss: 0.0255
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0699
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0414
# Epoch 4/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0070 - val_loss: 0.0352
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0444
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0539
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0251
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0225
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0173
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0220
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0308
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0321
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0279
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0358
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 0.0313
# Epoch 16/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 0.0238
# Epoch 17/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0178
# Epoch 18/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0245
# Epoch 19/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0365
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0107
# 水生根茎类  模型的 测试损失是 : 0.010701274499297142
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0144 - val_loss: 0.0114
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0165
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0194
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0244
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0329
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0515
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0320
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0233
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0146
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0105 - val_loss: 0.0201
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0191
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0088
# 水生根茎类  模型的 测试损失是 : 0.008778933435678482
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0949 - val_loss: 0.0190
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0096 - val_loss: 0.0153
# Epoch 3/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0090 - val_loss: 0.0165
# Epoch 4/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0093 - val_loss: 0.0223
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0208
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0195
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0236
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0169
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0111 - val_loss: 0.0189
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0216
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0236
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0341
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0116
# 水生根茎类  模型的 测试损失是 : 0.011567560024559498
# Epoch 1/100
# 21/21 [==============================] - 2s 34ms/step - loss: 0.0345 - val_loss: 0.0161
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0092 - val_loss: 0.0152
# Epoch 3/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0086 - val_loss: 0.0186
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0231
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0171
# Epoch 6/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0085 - val_loss: 0.0188
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0232
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0302
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0225
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0234
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0380
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0249
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0108
# 水生根茎类  模型的 测试损失是 : 0.010821234434843063
# Epoch 1/100
# 21/21 [==============================] - 3s 33ms/step - loss: 0.0200 - val_loss: 0.0134
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0091 - val_loss: 0.0146
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0147
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0221
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0212
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0343
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0238
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0345
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0349
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0279
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0309
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0102
# 水生根茎类  模型的 测试损失是 : 0.010157033801078796
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0363 - val_loss: 0.0199
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0090 - val_loss: 0.0148
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0162
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0166
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0233
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0253
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0285
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0440
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0367
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0292
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0437
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0327
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0115
# 水生根茎类  模型的 测试损失是 : 0.011469002813100815
# Epoch 1/100
# 21/21 [==============================] - 2s 32ms/step - loss: 0.0303 - val_loss: 0.0124
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0185
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0170
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0274
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0260
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0294
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0267
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0325
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0192
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0224
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0193
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0092
# 水生根茎类  模型的 测试损失是 : 0.009165575727820396
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0286 - val_loss: 0.0164
# Epoch 2/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0096 - val_loss: 0.0112
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0090 - val_loss: 0.0123
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0134
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0160
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0386
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0074 - val_loss: 0.0119
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0113 - val_loss: 0.0242
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0074 - val_loss: 0.0451
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0269
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0548
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0311
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0083
# 水生根茎类  模型的 测试损失是 : 0.008275343105196953
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0145 - val_loss: 0.0422
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0455
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0370
# Epoch 4/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0069 - val_loss: 0.0424
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0197
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0115 - val_loss: 0.0164
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0226
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0074 - val_loss: 0.0273
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0183
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0150
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0222
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0214
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0159
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0185
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0207
# Epoch 16/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0198
# Epoch 17/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0196
# Epoch 18/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0171
# Epoch 19/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0161
# Epoch 20/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0148
# Epoch 21/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0157
# Epoch 22/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0150
# Epoch 23/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0208
# Epoch 24/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 0.0292
# Epoch 25/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0267
# Epoch 26/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0124
# Epoch 27/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0190
# Epoch 28/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0193
# Epoch 29/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0164
# Epoch 30/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0156
# Epoch 31/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0164
# Epoch 32/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0061 - val_loss: 0.0184
# Epoch 33/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 0.0168
# Epoch 34/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0060 - val_loss: 0.0147
# Epoch 35/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0147
# Epoch 36/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 0.0134
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0091
# 水生根茎类  模型的 测试损失是 : 0.009089294821023941
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0297 - val_loss: 0.0202
# Epoch 2/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0092 - val_loss: 0.0178
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0090 - val_loss: 0.0266
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0268
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0345
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0572
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0457
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0579
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0564
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0214
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0117 - val_loss: 0.0127
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0148
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0282
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0212
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0342
# Epoch 16/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0616
# Epoch 17/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0428
# Epoch 18/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0555
# Epoch 19/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0677
# Epoch 20/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0702
# Epoch 21/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0389
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0097
# 水生根茎类  模型的 测试损失是 : 0.00969737395644188
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0252 - val_loss: 0.0185
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0158
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0239
# Epoch 4/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0076 - val_loss: 0.0221
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0311
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0210
# Epoch 7/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0085 - val_loss: 0.0260
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0275
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0221
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0310
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0359
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0223
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0121
# 水生根茎类  模型的 测试损失是 : 0.012114224024116993
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0142 - val_loss: 0.0217
# Epoch 2/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0087 - val_loss: 0.0225
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0224
# Epoch 4/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0073 - val_loss: 0.0416
# Epoch 5/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0071 - val_loss: 0.0270
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0661
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0665
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0584
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0074 - val_loss: 0.0145
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0345
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0484
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0611
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0251
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0276
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0581
# Epoch 16/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0066 - val_loss: 0.0618
# Epoch 17/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0065 - val_loss: 0.0346
# Epoch 18/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0350
# Epoch 19/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0270
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0092
# 水生根茎类  模型的 测试损失是 : 0.00917236227542162
# Epoch 1/100
# 21/21 [==============================] - 3s 33ms/step - loss: 0.0122 - val_loss: 0.0223
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0148
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0092 - val_loss: 0.0238
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0430
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0615
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0602
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0423
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0392
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0463
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0322
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0267
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0210
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0094
# 水生根茎类  模型的 测试损失是 : 0.009374330751597881
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0299 - val_loss: 0.0152
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0207
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0168
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0379
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0677
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0384
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0327
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0074 - val_loss: 0.0339
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0291
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0252
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0237
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0115
# 水生根茎类  模型的 测试损失是 : 0.011510651558637619
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0443 - val_loss: 0.0183
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0090 - val_loss: 0.0173
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0093 - val_loss: 0.0192
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0160
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0166
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0180
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0193
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0267
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0073 - val_loss: 0.0127
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0184
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0346
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0336
# Epoch 13/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0067 - val_loss: 0.0297
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0180
# Epoch 15/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0295
# Epoch 16/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0378
# Epoch 17/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0383
# Epoch 18/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0384
# Epoch 19/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0378
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0080
# 水生根茎类  模型的 测试损失是 : 0.00804660189896822
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0349 - val_loss: 0.0222
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0093 - val_loss: 0.0132
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0098 - val_loss: 0.0135
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0161
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0153
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0204
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0259
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0342
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0072 - val_loss: 0.0245
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0275
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0382
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0266
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0089
# 水生根茎类  模型的 测试损失是 : 0.008945413865149021
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0322 - val_loss: 0.0229
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0092 - val_loss: 0.0285
# Epoch 3/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0305
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0192
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 0.0381
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0074 - val_loss: 0.0394
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0070 - val_loss: 0.0263
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0354
# Epoch 9/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0294
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0284
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0319
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0444
# Epoch 13/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0067 - val_loss: 0.0470
# Epoch 14/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0455
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0113
# 水生根茎类  模型的 测试损失是 : 0.01129959523677826
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.1119 - val_loss: 0.0238
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 0.0169
# Epoch 3/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0089 - val_loss: 0.0288
# Epoch 4/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0085 - val_loss: 0.0222
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0315
# Epoch 6/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0304
# Epoch 7/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0344
# Epoch 8/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0074 - val_loss: 0.0475
# Epoch 9/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0072 - val_loss: 0.0374
# Epoch 10/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0400
# Epoch 11/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0461
# Epoch 12/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0324
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0117
# 水生根茎类  模型的 测试损失是 : 0.011696964502334595
# Epoch 1/100
# 21/21 [==============================] - 2s 33ms/step - loss: 0.0161 - val_loss: 0.0295
# Epoch 2/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0340
# Epoch 3/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0077 - val_loss: 0.0303
# Epoch 4/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0074 - val_loss: 0.0292
# Epoch 5/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0069 - val_loss: 0.0377
# Epoch 6/100
# ...
# Epoch 18/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0187
# Epoch 19/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0166
# Epoch 20/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0164
# Epoch 21/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0127
# Epoch 22/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0118
# Epoch 23/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0127
# Epoch 24/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0153
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0078
# 茄类  模型的 测试损失是 : 0.007788514252752066
# Epoch 1/100
# 20/20 [==============================] - 2s 34ms/step - loss: 0.0358 - val_loss: 0.0220
# Epoch 2/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0117 - val_loss: 0.0193
# Epoch 3/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0103 - val_loss: 0.0200
# Epoch 4/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0095 - val_loss: 0.0171
# Epoch 5/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0091 - val_loss: 0.0157
# Epoch 6/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0097 - val_loss: 0.0200
# Epoch 7/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0223
# Epoch 8/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0168
# Epoch 9/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0164
# Epoch 10/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0096 - val_loss: 0.0229
# Epoch 11/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0148
# Epoch 12/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0141
# Epoch 13/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0197
# Epoch 14/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0090 - val_loss: 0.0125
# Epoch 15/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0157
# Epoch 16/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0080 - val_loss: 0.0165
# Epoch 17/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0185
# Epoch 18/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0218
# Epoch 19/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0184
# Epoch 20/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0157
# Epoch 21/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0139
# Epoch 22/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0078 - val_loss: 0.0166
# Epoch 23/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0075 - val_loss: 0.0160
# Epoch 24/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0176
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0087
# 茄类  模型的 测试损失是 : 0.008682829327881336
# Epoch 1/100
# 20/20 [==============================] - 2s 34ms/step - loss: 0.0274 - val_loss: 0.0158
# Epoch 2/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0113 - val_loss: 0.0158
# Epoch 3/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0101 - val_loss: 0.0235
# Epoch 4/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0092 - val_loss: 0.0092
# Epoch 5/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0097 - val_loss: 0.0189
# Epoch 6/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0161
# Epoch 7/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0143
# Epoch 8/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0205
# Epoch 9/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0176
# Epoch 10/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0284
# Epoch 11/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0147
# Epoch 12/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0194
# Epoch 13/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0162
# Epoch 14/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0202
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0076
# 茄类  模型的 测试损失是 : 0.007552232593297958
# Epoch 1/100
# 20/20 [==============================] - 2s 34ms/step - loss: 0.0779 - val_loss: 0.0250
# Epoch 2/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0128 - val_loss: 0.0201
# Epoch 3/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0117 - val_loss: 0.0191
# Epoch 4/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0114 - val_loss: 0.0132
# Epoch 5/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0107 - val_loss: 0.0141
# Epoch 6/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0101 - val_loss: 0.0123
# Epoch 7/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0098 - val_loss: 0.0177
# Epoch 8/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0087 - val_loss: 0.0108
# Epoch 9/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0092 - val_loss: 0.0236
# Epoch 10/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0090 - val_loss: 0.0106
# Epoch 11/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0086 - val_loss: 0.0160
# Epoch 12/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0143
# Epoch 13/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0155
# Epoch 14/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0123
# Epoch 15/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0130
# Epoch 16/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0154
# Epoch 17/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0084 - val_loss: 0.0149
# Epoch 18/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0081 - val_loss: 0.0158
# Epoch 19/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0131
# Epoch 20/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0129
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0080
# 茄类  模型的 测试损失是 : 0.007965595461428165
# Epoch 1/100
# 20/20 [==============================] - 2s 34ms/step - loss: 0.0929 - val_loss: 0.0302
# Epoch 2/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0122 - val_loss: 0.0169
# Epoch 3/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0115 - val_loss: 0.0287
# Epoch 4/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0102 - val_loss: 0.0237
# Epoch 5/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0098 - val_loss: 0.0289
# Epoch 6/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 0.0288
# Epoch 7/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0095 - val_loss: 0.0226
# Epoch 8/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0091 - val_loss: 0.0134
# Epoch 9/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0096 - val_loss: 0.0456
# Epoch 10/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0099 - val_loss: 0.0225
# Epoch 11/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0288
# Epoch 12/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0256
# Epoch 13/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0084 - val_loss: 0.0154
# Epoch 14/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0323
# Epoch 15/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 0.0147
# Epoch 16/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 0.0306
# Epoch 17/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0091 - val_loss: 0.0177
# Epoch 18/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0083 - val_loss: 0.0168
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0099
# 茄类  模型的 测试损失是 : 0.009915528818964958
# Epoch 1/100
# 20/20 [==============================] - 2s 34ms/step - loss: 0.0249 - val_loss: 0.0165
# Epoch 2/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0111 - val_loss: 0.0160
# Epoch 3/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0102 - val_loss: 0.0150
# Epoch 4/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0091 - val_loss: 0.0134
# Epoch 5/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0086 - val_loss: 0.0121
# Epoch 6/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0083 - val_loss: 0.0155
# Epoch 7/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0090 - val_loss: 0.0195
# Epoch 8/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0121
# Epoch 9/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0154
# Epoch 10/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0195
# Epoch 11/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0130
# Epoch 12/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0127
# Epoch 13/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0080 - val_loss: 0.0125
# Epoch 14/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0132
# Epoch 15/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0079 - val_loss: 0.0201
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0083
# 茄类  模型的 测试损失是 : 0.0083487993106246
# Epoch 1/100
# 20/20 [==============================] - 2s 34ms/step - loss: 0.0900 - val_loss: 0.0220
# Epoch 2/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0123 - val_loss: 0.0155
# Epoch 3/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0109 - val_loss: 0.0144
# Epoch 4/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0104 - val_loss: 0.0155
# Epoch 5/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0092 - val_loss: 0.0196
# Epoch 6/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0138
# Epoch 7/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0091 - val_loss: 0.0303
# Epoch 8/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0200
# Epoch 9/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0142
# Epoch 10/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0091 - val_loss: 0.0173
# Epoch 11/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0183
# Epoch 12/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0188
# Epoch 13/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0234
# Epoch 14/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0130
# Epoch 15/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0173
# Epoch 16/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0186
# Epoch 17/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0076 - val_loss: 0.0154
# Epoch 18/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0124
# Epoch 19/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0133
# Epoch 20/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0235
# Epoch 21/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0179
# Epoch 22/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0141
# Epoch 23/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0183
# Epoch 24/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0173
# Epoch 25/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0081 - val_loss: 0.0153
# Epoch 26/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0123
# Epoch 27/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0155
# Epoch 28/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0195
# Epoch 29/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0081 - val_loss: 0.0140
# Epoch 30/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0159
# Epoch 31/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0083 - val_loss: 0.0149
# Epoch 32/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0193
# Epoch 33/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0078 - val_loss: 0.0166
# Epoch 34/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0123
# Epoch 35/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0077 - val_loss: 0.0138
# Epoch 36/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0129
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0082
# 茄类  模型的 测试损失是 : 0.008194973692297935
# Epoch 1/100
# 20/20 [==============================] - 2s 34ms/step - loss: 0.0796 - val_loss: 0.0244
# Epoch 2/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0121 - val_loss: 0.0186
# Epoch 3/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0117 - val_loss: 0.0154
# Epoch 4/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0110 - val_loss: 0.0155
# Epoch 5/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0102 - val_loss: 0.0185
# Epoch 6/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0095 - val_loss: 0.0220
# Epoch 7/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0103 - val_loss: 0.0179
# Epoch 8/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0148
# Epoch 9/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0086 - val_loss: 0.0145
# Epoch 10/100
# 20/20 [==============================] - 0s 16ms/step - loss: 0.0085 - val_loss: 0.0194
# Epoch 11/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0143
# Epoch 12/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0209
# Epoch 13/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0121
# Epoch 14/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0141
# Epoch 15/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0082 - val_loss: 0.0157
# Epoch 16/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0084 - val_loss: 0.0126
# Epoch 17/100
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0295
# Epoch 18/100
#  5/20 [======>.......................] - ETA: 0s - loss: 0.0082

# %%
# 预测模型
X_predict = []
for name in name_type_list:
     X_predict.append(DataFrame_list_type_fillted_normalized_train_split[name]["X测试集"][-1])

Prediction_value = {}
for data_Set_index in range(len(X_predict)):
    temp = []
    for model in Model_diction_sampling[name_type_list[data_Set_index]]:
        predict_y = model.model.predict(X_predict[data_Set_index])
        temp.append(predict_y)
    Prediction_value[name_type_list[data_Set_index]] = temp

# %%
Prediction_value

# %%
# 定义销量函数
def Root_stock_prediction(x):
    return -2.914*x + 62.26

def Mosaic_Leaf_prediction(x):
    return -11.24*x + 232.6

def Flower_Vegetables_prediction(x):
    return -1.096*x + 65.47

def Solanaceous_prediction(x):
    return -2.18*x + 30.43

def Chili_Peppers_prediction(x):
    return -2.18*x + 97.75

def Mushrooms_prediction(x):
    return -3.453*x + 93.52

# %%
prediction_functions = [Root_stock_prediction, Mosaic_Leaf_prediction, Flower_Vegetables_prediction,
                        Solanaceous_prediction, Chili_Peppers_prediction, Mushrooms_prediction]

def objective(prices, costs, prediction_functions):
    revenue = 0
    for i in range(len(prices)):
        quantity = prediction_functions[i](prices[i])
        if quantity < 0:
            quantity = 0
        revenue += (prices[i] - costs[i]) * quantity
    return -revenue

def optimization_price(Dataframe):
    rows = []
    for index in range(len(Dataframe)):
        costs = Dataframe.iloc[index].values
        initial_prices = costs * 1.5
        constraints = ({'type': 'ineq', 'fun': lambda prices, costs=costs:  prices - costs})
        result = minimize(objective, initial_prices, args=(costs, prediction_functions), constraints=constraints)
        
        if result.success:
            optimized_prices = result.x
            rows.append(optimized_prices)
            
    Result_dataframe = pd.DataFrame(rows, columns=['水生根茎类', '花叶类', '花菜类', '茄类', '辣椒类', '食用菌'])
    return Result_dataframe

optimization_price(Data_predicted_result)

# %% [markdown]
# ## 问题三：菜品最优化定义

# %%
# 数据准备，队友通过筛选获得了六十一种蔬菜单品
Name_product_liist = pd.read_excel("菜品名单.xlsx", engine='openpyxl').iloc[:61, 0].values
Name_product_liist

# %%
DataFrame_list_product_fillted = {}
for name in Name_product_liist:
    temp_frame = Daily_sales_stat_product[Daily_sales_stat_product['单品名称'] == name][["销售日期","日销量(千克)"]].reset_index(drop=True)
    temp_frame['销售日期'] = pd.to_datetime(temp_frame['销售日期'])
    # 创建一个包含所有日期的新DataFrame
    date_range = pd.date_range(start='2020-07-01', end='2023-06-30')
    full_date_frame = pd.DataFrame({'销售日期': date_range})
    merged_frame = pd.merge(full_date_frame, temp_frame, on='销售日期', how='left').fillna(0)
    merged_frame.set_index('销售日期', inplace=True)
    DataFrame_list_product_fillted[name] = merged_frame

# %%
DataFrame_list_product_fillted['苋菜']
